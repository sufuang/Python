# %%
# python get all the file names in a folder start with 
import os
path = "/dbfs/FileStore/tables/DATA_SCIENCE/"
gs1_file = [filename for filename in os.listdir(path) if filename.startswith("GS1") and filename.endswith(".csv")]
gs1_file
# Out:
# Out[1]: ['GS1_COMMERCIAL_BAKERY_FUZZY_MAPPING_SUBCOM_052423_.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_1000rows.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_BrickText.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_SUBCOM_only.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_SUBCOM_only_1000rows.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052523_ITEM_SUBCOM_only.csv',
#  'GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_053023_SUBCOM_only.csv',
#  'GS1_FoodBev_2022.csv',
#  'GS1_PACK_DELI_VECTOR_MATCHING_060623.csv']

# %%
import pandas as pd
for file in gs1_file:
    df = pd.read_csv(path + file, dtype='unicode')
    print (f'file name : {file}')
    print (f'df.shape: {df.shape} \n')
    print (f'df.dtypes: {df.dtypes} \n')
    print (f'df.head() \n : {df.head()} \n')
# Out:
# file name : GS1_COMMERCIAL_BAKERY_FUZZY_MAPPING_SUBCOM_052423_.csv
# df.shape: (13739, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BRICK           object
# MATCH_SCORE     object
# dtype: object
#
# df.head()
#  :                                         VND_ECOM_DSC  \
# 0        Lewis Bake Shop Texas Toast Half Loaf Bread
# 1        Lewis Bake Shop Texas Toast Half Loaf Bread
# 2        Lewis Bake Shop Texas Toast Half Loaf Bread
# 3         Lewis Bake Shop Half Loaf Hearty Rye Bread
# 4  CASE - ROUND TOP ENRICHED WHITE BREAD - KROGER...
#
#                                  BRICK        MATCH_SCORE
# 0                       Bread (Frozen)  66.66666666666666
# 1                   Bread (Perishable)  66.66666666666666
# 2                 Bread (Shelf Stable)  66.66666666666666
# 3  Bread/Bakery Products Variety Packs               50.0
# 4                       Bread (Frozen)  66.66666666666666
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423.csv
# df.shape: (500, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                           BrickTitle        Similarities
# 0  Dough Based Products / Meals - Ready to Eat - ...  0.9901964664459229
# 1  Vegetable Based Products / Meals - Ready to Ea...  0.9899561405181885
# 2  Dough Based Products / Meals - Ready to Eat - ...  0.9897632002830505
# 3  Vegetable Based Products / Meals - Ready to Ea...  0.9893140196800232
# 4  Dairy/Egg Based Products / Meals - Ready to Ea...  0.9851003885269165
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_1000rows.csv
# df.shape: (5000, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                           BrickTitle        Similarities
# 0  Dough Based Products / Meals - Ready to Eat - ...  0.9901326894760132
# 1  Vegetable Based Products / Meals - Ready to Ea...   0.989996612071991
# 2  Dough Based Products / Meals - Ready to Eat - ...  0.9897449612617493
# 3  Vegetable Based Products / Meals - Ready to Ea...  0.9894425868988037
# 4  Dairy/Egg Based Products / Meals - Ready to Ea...  0.9851576089859009
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_BrickText.csv
# df.shape: (5000, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                           BrickTitle        Similarities
# 0          Pasta/Noodles - Ready to Eat (Perishable)  0.9861299395561218
# 1  Ready-Made Combination Meals - Ready to Eat (S...   0.983841061592102
# 2  Ready-Made Combination Meals - Not Ready to Ea...   0.982145369052887
# 3  Grain Based Products / Meals - Ready to Eat - ...  0.9819786548614502
# 4  Grain Based Products / Meals - Not Ready to Ea...  0.9814696311950684
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_SUBCOM_only.csv
# df.shape: (40840, 4)
#
# df.dtypes: VND_ECOM_DSC    object
# SUBCOM_DSC      object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC              SUBCOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread  MAINSTREAM WHITE BREAD
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread  MAINSTREAM WHITE BREAD
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread  MAINSTREAM WHITE BREAD
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread  MAINSTREAM WHITE BREAD
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread  MAINSTREAM WHITE BREAD
#
#                                           BrickTitle Similarities
# 0  Ready-Made Combination Meals - Not Ready to Ea...          1.0
# 1  Ready-Made Combination Meals - Ready to Eat Va...          1.0
# 2         Confectionery Based Spreads (Shelf Stable)          1.0
# 3  Ready-Made Combination Meals - Ready to Eat (S...          1.0
# 4  Ready-Made Combination Meals - Ready to Eat (P...          1.0
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052423_SUBCOM_only_1000rows.csv
# df.shape: (5000, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                           BrickTitle        Similarities
# 0  Dough Based Products / Meals - Ready to Eat - ...  0.9782804250717163
# 1                                     Bread (Frozen)  0.9775201082229614
# 2  Dairy Based Products / Meals - Not Ready to Ea...  0.9765498638153076
# 3  Dough Based Products / Meals - Ready to Eat - ...  0.9756150245666504
# 4         Jams/Marmalades/Fruit Spreads (Perishable)  0.9753429889678955
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_052523_ITEM_SUBCOM_only.csv
# df.shape: (40840, 4)
#
# df.dtypes: VND_ECOM_DSC    object
# ITEM_SUBCOM     object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                          ITEM_SUBCOM  \
# 0  lewis bake shop texas toast half loaf bread ma...
# 1  lewis bake shop texas toast half loaf bread ma...
# 2  lewis bake shop texas toast half loaf bread ma...
# 3  lewis bake shop texas toast half loaf bread ma...
# 4  lewis bake shop texas toast half loaf bread ma...
#
#                                           BrickTitle Similarities
# 0  Ready-Made Combination Meals - Ready to Eat (P...          1.0
# 1  Ready-Made Combination Meals - Not Ready to Ea...          1.0
# 2  Ready-Made Combination Meals - Not Ready to Ea...          1.0
# 3  Ready-Made Combination Meals - Not Ready to Ea...          1.0
# 4  Ready-Made Combination Meals - Not Ready to Ea...          1.0
#
# file name : GS1_COMMERCIAL_BAKERY_VECTOR_MATCHING_053023_SUBCOM_only.csv
# df.shape: (24504, 4)
#
# df.dtypes: VND_ECOM_DSC    object
# SUBCOM_DSC      object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                         VND_ECOM_DSC  \
# 0        Lewis Bake Shop Texas Toast Half Loaf Bread
# 1        Lewis Bake Shop Texas Toast Half Loaf Bread
# 2        Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Snack Cakes, Little Debbie Family Pack Back to...
# 4  Snack Cakes, Little Debbie Family Pack Back to...
#
#                               SUBCOM_DSC  \
# 0                 MAINSTREAM WHITE BREAD
# 1                 MAINSTREAM WHITE BREAD
# 2                 MAINSTREAM WHITE BREAD
# 3  SWEET GOODS - FULL SIZE EXCEPT DONUTS
# 4  SWEET GOODS - FULL SIZE EXCEPT DONUTS
#
#                                    BrickTitle        Similarities
# 0                              Bread (Frozen)   0.725456953048706
# 1      Sandwiches/Filled Rolls/Wraps (Frozen)   0.689520001411438
# 2  Sandwiches/Filled Rolls/Wraps (Perishable)  0.6803117990493774
# 3              Pies/Pastries - Sweet (Frozen)   0.560584306716919
# 4        Pies/Pastries - Sweet (Shelf Stable)  0.5605260729789734
#
# file name : GS1_FoodBev_2022.csv
# df.shape: (135600, 19)
#
# df.dtypes: SegmentCode                 object
# SegmentTitle                object
# SegmentDefinition           object
# FamilyCode                  object
# FamilyTitle                 object
# FamilyDefinition            object
# ClassCode                   object
# ClassTitle                  object
# ClassDefinition             object
# BrickCode                   object
# BrickTitle                  object
# BrickDefinition_Includes    object
# BrickDefinition_Excludes    object
# AttributeCode               object
# AttributeTitle              object
# AttributeDefinition         object
# AttributeValueCode          object
# AttributeValueTitle         object
# AttributeValueDefinition    object
# dtype: object
#
# df.head()
#  :   SegmentCode           SegmentTitle SegmentDefinition FamilyCode FamilyTitle  \
# 0    50000000  Food/Beverage/Tobacco               NaN   50200000   Beverages
# 1    50000000  Food/Beverage/Tobacco               NaN   50200000   Beverages
# 2    50000000  Food/Beverage/Tobacco               NaN   50200000   Beverages
# 3    50000000  Food/Beverage/Tobacco               NaN   50200000   Beverages
# 4    50000000  Food/Beverage/Tobacco               NaN   50200000   Beverages
#
#   FamilyDefinition ClassCode  \
# 0              NaN  50202200
# 1              NaN  50202200
# 2              NaN  50202200
# 3              NaN  50202200
# 4              NaN  50202200
#
#                                           ClassTitle ClassDefinition  \
# 0  Alcoholic Beverages (Includes De-Alcoholised V...             NaN
# 1  Alcoholic Beverages (Includes De-Alcoholised V...             NaN
# 2  Alcoholic Beverages (Includes De-Alcoholised V...             NaN
# 3  Alcoholic Beverages (Includes De-Alcoholised V...             NaN
# 4  Alcoholic Beverages (Includes De-Alcoholised V...             NaN
#
#   BrickCode              BrickTitle  \
# 0  10008042  Alcohol Flavouring Kit
# 1  10000142     Alcohol Making Kits
# 2  10000142     Alcohol Making Kits
# 3  10000142     Alcohol Making Kits
# 4  10000142     Alcohol Making Kits
#
#                             BrickDefinition_Includes  \
# 0  Includes any products that can be described/ob...
# 1  Includes any products that can be described/ob...
# 2  Includes any products that can be described/ob...
# 3  Includes any products that can be described/ob...
# 4  Includes any products that can be described/ob...
#
#                             BrickDefinition_Excludes AttributeCode  \
# 0  Excludes products such as Alcohol Making Acces...           NaN
# 1  Excludes products such as Alcohol Making Acces...    20000004.0
# 2  Excludes products such as Alcohol Making Acces...    20000004.0
# 3  Excludes products such as Alcohol Making Acces...    20000004.0
# 4  Excludes products such as Alcohol Making Acces...    20000004.0
#
#                AttributeTitle  \
# 0                         NaN
# 1  Type of Alcohol Making Kit
# 2  Type of Alcohol Making Kit
# 3  Type of Alcohol Making Kit
# 4  Type of Alcohol Making Kit
#
#                                  AttributeDefinition AttributeValueCode  \
# 0                                                NaN                NaN
# 1  Indicates, with reference to the product brand...         30000309.0
# 2  Indicates, with reference to the product brand...         30003009.0
# 3  Indicates, with reference to the product brand...         30002832.0
# 4  Indicates, with reference to the product brand...         30002515.0
#
#   AttributeValueTitle                           AttributeValueDefinition
# 0                 NaN                                                NaN
# 1            BEER KIT                                                NaN
# 2         LIQUEUR KIT                                                NaN
# 3          SPIRIT KIT                                                NaN
# 4        UNCLASSIFIED  This term is used to describe those product at...
#
# file name : GS1_PACK_DELI_VECTOR_MATCHING_060623.csv
# df.shape: (500, 3)
#
# df.dtypes: VND_ECOM_DSC    object
# BrickTitle      object
# Similarities    object
# dtype: object
#
# df.head()
#  :                                   VND_ECOM_DSC  \
# 0  Lewis Bake Shop Texas Toast Half Loaf Bread
# 1  Lewis Bake Shop Texas Toast Half Loaf Bread
# 2  Lewis Bake Shop Texas Toast Half Loaf Bread
# 3  Lewis Bake Shop Texas Toast Half Loaf Bread
# 4  Lewis Bake Shop Texas Toast Half Loaf Bread
#
#                                           BrickTitle        Similarities
# 0  Vegetable Based Products / Meals - Ready to Ea...  0.9834901690483093
# 1  Dough Based Products / Meals - Ready to Eat - ...   0.981992781162262
# 2  Dough Based Products / Meals - Ready to Eat - ...   0.981777012348175
# 3  Vegetable Based Products / Meals - Ready to Ea...  0.9810391664505005
# 4  Dairy/Egg Based Products / Meals - Ready to Ea...   0.979699432849884
