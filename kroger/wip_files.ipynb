# %% [markdown]
# # wip_files.ipynb
#   -  module name: wip_files.ipynb
#   -  explore files
#   -  #5 PIM_Flavor_Attributes_current.csv

# %%
import pandas as pd, numpy as np
path = 'C:\\users\\iny2819\\kroger\\Data\\'

# %%
DBFR = "/dbfs/FileStore/tables/OFFSHORE_RESULTS/"
path = 'C:\\users\\iny2819\\kroger\\Data\\'   
DBFR = path
path_atb = path + 'ATB\\'

# %%
path_code = 'C:\\users\\iny2819\\kroger\\Code\\'  
f_com_code = path_code + "com_code.py"
exec(compile(open(f_com_code , "rb").read(), f_com_code, 'exec' ))

# %%
df1 = f_read(path_atb,  "COLOR_NORMALIZED_Home_Decor_Rugs_12152023.csv")
df2 = f_read(path_atb,  "Validation_Data_Color_HomeDecor_Rugs_12122023_Prateek.xlsx")
# Out:
# file COLOR_NORMALIZED_Home_Decor_Rugs_12152023.csv shape (160544, 8)
#  columns: Index(['GTIN_NO', 'VND_ECOM_DSC', 'ITM_LVL_DSC', 'TAG_DSC', 'COLOR_CURRENT',
#        'EXTRACTED_COLOR', 'NORMALIZED_COLOR', 'SLS_CHA_VLU'],
#       dtype='object')
# dtypes:
#  GTIN_NO             object
# VND_ECOM_DSC        object
# ITM_LVL_DSC         object
# TAG_DSC             object
# COLOR_CURRENT       object
# EXTRACTED_COLOR     object
# NORMALIZED_COLOR    object
# SLS_CHA_VLU         object
# dtype: object
# head:
#         GTIN_NO                                       VND_ECOM_DSC ITM_LVL_DSC  \
# 0  39425238279     Momeni Baja Trellis Green Area Rug 5'3" X 7'6"         NaN
# 1  39425238071  Momeni Baja Links Navy Area Rug 2'3" X 7'6" Ru...         NaN
# 2  39425240685       Momeni Baja Stripe Navy Area Rug 6'7" X 9'6"         NaN
# 3  39425240920       Momeni Baja Trellis Navy Area Rug 8'6" X 13'         NaN
# 4  39425305216      Momeni Baja 6'7 X 9'6 Transitional Rug in Red         NaN
# ...

# %%
corrected_single = f_read(path_atb,'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= 'Single_Flavors')
# Out:
# file ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx shape (7979, 8)
#  columns: Index(['GTIN_NO', 'ECOMMERCE_DESCRIPTION', 'VND_ECOM_DSC', 'TAG_DESCRIPTION',
#        'PRODUCT_DESCRIPTION/MKT_MSG', 'Flavor', 'Match_Score', 'CORRECTED'],
#       dtype='object')
# dtypes:
#  GTIN_NO                          int64
# ECOMMERCE_DESCRIPTION           object
# VND_ECOM_DSC                    object
# TAG_DESCRIPTION                 object
# PRODUCT_DESCRIPTION/MKT_MSG     object
# Flavor                          object
# Match_Score                    float64
# CORRECTED                       object
# dtype: object
# head:
#         GTIN_NO                              ECOMMERCE_DESCRIPTION  \
# 0  76840000715         Ben & Jerry's Caramel Chocolate Cheesecake
# 1  76840000722  Ben & Jerry's Chillin' the Roast Truffles Ice ...
# 2  76840000739  Ben & Jerry's® Chocolate Shake It Truffles Ice...
# 3  76840001002  Ben & Jerrys The Tonight Dough Pint Slices Ca...
# ...

# %%
ic_df = f_read(path_atb,'ICE_CREAM_VND_DESCS.csv') #1
# Out:
# file ICE_CREAM_VND_DESCS.csv shape (11086, 2)
#  columns: Index(['GTIN_NO', 'VND_ECOM_DSC'], dtype='object')
# dtypes:
#  GTIN_NO         object
# VND_ECOM_DSC    object
# dtype: object

# %%
masterlist = f_read(path_atb,'ice_cream_items_org.csv', sep = '|', encoding= 'ISO-8859-1')
# Out:
# file ice_cream_items_org.csv shape (12386, 12)
#  columns: Index(['GTIN_NO', 'ECOMMERCE_DESCRIPTION', 'RECEIPT_DESCRIPTION',
#        'TAG_DESCRIPTION', 'PRODUCT_DESCRIPTION/MKT_MSG', 'KROGER_OWNED_FLAVOR',
#        'FLV_DSC', 'PID_COM_DSC', 'PID_SUBCOM_DSC', 'CFIC_DEPT_NAM',
#        'CFIC_COM_NAM', 'CFIC_SUBCOM_NAM'],
#       dtype='object')
# dtypes:
#  GTIN_NO                        object
# ECOMMERCE_DESCRIPTION          object
# RECEIPT_DESCRIPTION            object
# TAG_DESCRIPTION                object
# PRODUCT_DESCRIPTION/MKT_MSG    object
# KROGER_OWNED_FLAVOR            object
# FLV_DSC                        object
# PID_COM_DSC                    object
# PID_SUBCOM_DSC                 object
# CFIC_DEPT_NAM                  object
# CFIC_COM_NAM                   object
# CFIC_SUBCOM_NAM                object
# dtype: object
# head:
#            GTIN_NO ECOMMERCE_DESCRIPTION RECEIPT_DESCRIPTION  \
# 0  00000000001175        Frys Snow Cone        SNOW CONE LG
# ...

# %%
ic_df = f_read(path_atb,'ICE_CREAM_VND_DESCS.csv')
bnj_flvs_ct = f_read(path_atb,'Ben_Jerrys_Flavors_CTribune.csv').Flavor.str.upper().str.strip(' ').tolist()
new_flvs_ = f_read(path_atb,'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet1')
#new_flvs_paul_single = pd.read_excel('New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet2')
#new_flvs_paul_double = pd.read_excel('New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet3')
#new_flvs_paul_multiple = pd.read_excel('New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet4')
#new_flvs_paul_others = pd.read_excel('New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet5')

masterlist = f_read(path_atb,'ice_cream_items_org.csv', sep = '|', encoding= 'ISO-8859-1')
latest_labeled =f_read(path_atb,'ICECREAM_OTHER_FLAVORS_101623.xlsx')


corrected_single = f_read(path_atb,'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= 'Single_Flavors')
#corrected_double = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= '2_Flavors')
#corrected_multiple = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= '3_plus__Flavors')
#corrected_others = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= 'OTHERs')
#corr_cols = ['GTIN_NO','CORRECTED']


#PAUL'S FINAL REVIEW
ic_final_1 = f_read(path_atb,'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= 'Single_Flavors')
#ic_final_2 = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= '2_Flavors')
#ic_final_3 = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= '3_plus__Flavors')
#ic_final_4 = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= 'MANUALLY_EXTRACTED')
#ic_final_5 = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= 'OTHERS')
#ic_final_6 = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_110123 2 - Paul reviewed.xlsx', sheet_name= 'UNCLASSIFIED')
# Out:
# file ICE_CREAM_VND_DESCS.csv shape (11086, 2)
#  columns: Index(['GTIN_NO', 'VND_ECOM_DSC'], dtype='object')
# dtypes:
#  GTIN_NO         object
# VND_ECOM_DSC    object
# dtype: object
# head:
#    GTIN_NO               VND_ECOM_DSC
# 0   13772  COFFEE BAR - BREWED COFFE
# 1   22231          DELI GELATO SMALL
# 2   22248         DELI GELATO MEDIUM
# 3   22255          DELI GELATO LARGE
# 4   22262           DELI GELATO PINT
# file Ben_Jerrys_Flavors_CTribune.csv shape (54, 1)
#  columns: Index(['Flavor'], dtype='object')
# dtypes:
#  Flavor    object
# dtype: object
# head:
#                           Flavor
# 0  Caramel Chocolate Cheesecake
# 1            Chillin' the Roast
# 2            Chocolate Shake It
# 3                  Gimme S'more
# 4           Glampfire Trail Mix
# file New_Flavors_Combos_102723.xlsx shape (667, 1)
#  columns: Index(['Flavors'], dtype='object')
# dtypes:
#  Flavors    object
# dtype: object
# head:
#                          Flavors
# ...

# %%
df_````pim_data_new_parquet  = pd.read_parquet(path + 'ITM_DSC_ATTRIBUTES_NEW_parquet.gzip', columns=['GTIN_NO', 'GTIN_NAM', 'ITM_LVL_DSC'])
df_pim_data_new_parquet.head()
# Out:
#        GTIN_NO                                           GTIN_NAM  \
# 0  24126017438  Lewis Bakeshop Half Loaf Texas Toast Bread, 1/...
# 1  38000170423  Kellogg's Special K Cereal Blueberry Lemon 12.3oz
# 2  24300045233                            Back to School Brownies
# 3  24300045240                    Back to School APPLE DELIGHTS ®
# 4  88502483255  U BY KOTEX PREMIUM SECURITY SUPER PLUS TAMPONS 18
#
#                      ITM_LVL_DSC
# 0                    Texas Toast
# 1  Blueberry with Lemon Clusters
# 2        Back to School Brownies
# 3  Back to School Apple Delights
# 4                           None

# %%
df_pim_data_new_parquet.dtypes
# Out:
# GTIN_NO         int64
# GTIN_NAM       object
# ITM_LVL_DSC    object
# dtype: object

# %%
03_g_xtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323_x.csv')
# Out:
#   Cell In[6], line 1
#     03_g_xtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323_x.csv')
#       ^
# SyntaxError: invalid decimal literal

# %%
df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_101123.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_101123.csv')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
#df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323.csv',  dtype={"GTIN_NO": 'int64', "ITM_ID": 'int64'})
df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 #df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323.csv',  dtype={"GTIN_NO": 'int64', "ITM_ID": 'int64'})
# ----> 2 df_gtin_map  = pd.read_csv(path + 'IIM_ID_GTIN_Map_100323.csv')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
df_gtin_map  = pd.read_excel(path + 'IIM_ID_GTIN_Map_102323.xlsx',  dtype={"GTIN_NO": 'int64', "ITM_ID": 'int64'})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_gtin_map  = pd.read_excel(path + 'IIM_ID_GTIN_Map_102323.xlsx',  dtype={"GTIN_NO": 'int64', "ITM_ID": 'int64'})
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
path_code = 'C:\\users\\iny2819\\kroger\\Code\\'  
f_com_code = path_code + "com_code.py"
exec(compile(open(f_com_code , "rb").read(), f_com_code, 'exec' ))

# %%
df_file5 = csv_read("PIM_Flavor_Attributes_current.csv")
# Out:
# file PIM_Flavor_Attributes_current.csv shape (1687, 5)
#  columns: ['DEPARTMENT' 'SUBCOMMODITY' 'Item Count' 'Flavor Attribution Status'
#  'Flavor Distribution Counts']
# head:
#                  DEPARTMENT                SUBCOMMODITY  Item Count  \
# 0  <OBSOLETE> FOOD SERVICE      <OBSOLETE> INGREDIENTS           2
# 1                     BABY             BABY FOOD POUCH        2294
# 2                     BABY         MISC. BABY PRODUCTS        1208
# 3                     BABY         BABY FOOD - POUCHES         930
# 4                     BABY  BABY FOOD PUREES-STG 1/2/3         768
#
#   Flavor Attribution Status                         Flavor Distribution Counts
# 0                  {'N': 2}                                                 {}
# 1     {'N': 2079, 'Y': 215}  {'MISCELLANEOUS': 69, 'FRUIT': 30, 'VEGETABLE'...
# 2       {'N': 1204, 'Y': 4}       {'MISCELLANEOUS': 2, 'FRUIT': 1, 'BERRY': 1}
# ...

# %%
df_file6 =  csv_read('PIM_Data_New_50_82Mn.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_file6 =  csv_read('PIM_Data_New_50_82Mn.zip')
#
# Cell In[20], line 4, in csv_read(file)
#       2 exe = file.split('.')[-1]
#       3 if exe == 'zip':
# ----> 4    pd.read_csv(path + file, compression="zip")
#       5 elif exe == 'csv':
#       6    df = pd.read_csv( path + file)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df_file5['Item Count'].sum()
# Out:
# 941799

# %%
#1 read 'PIM_Data_New_50_82Mn.zip
#df_zip = pd.read_csv( path + "PIM_Data_New_50_82Mn.zip", compression="zip", nrows = 2)
df_zip = pd.read_csv( path + "PIM_Data_New_50_82Mn.csv",  nrows = 2)
df_zip.columns
# Out:
# Index(['ITM_ID', 'GTIN', 'PMY_DPT_CD', 'PMY_DPT_DSC', 'REC_DPT_CD',
#        'REC_DPT_DSC', 'DPT_CD', 'DPT_DSC', 'COM_CD', 'COM_DSC', 'SUBCOM_CD',
#        'SUBCOM_DSC', 'VND_ECOM_DSC', 'ITM_ID_y', 'Level 1', 'Level 2',
#        'Level 3', 'Level 4', 'Level 5', 'Level 6', 'Level 7', 'Level 8',
#        'Level 9', 'Level 10'],
#       dtype='object')

# %%
#2 PIM_DATA_WITH_FLAVOR_ATTB_100323.csv
df_file2 = pd.read_csv( path + "PIM_DATA_WITH_FLAVOR_ATTB_100323.csv",  nrows = 2)
df_file2.columns
# Out:
# Index(['ITM_ID', 'GTIN_NO', 'GTIN_NAM', 'PMY_DPT_CD', 'PMY_DPT_DSC',
#        'REC_DPT_CD', 'REC_DPT_DSC', 'DPT_CD', 'DPT_DSC', 'COM_CD', 'COM_DSC',
#        'SUBCOM_CD', 'SUBCOM_DSC', 'ITM_LVL_DSC', 'VND_ECOM_DSC',
#        'Flavor_Value', 'Flavor_Code'],
#       dtype='object')

# %%
#3 'ITM_DSC_ATTRIBUTES_NEW_parquet.gzip' 

df_file3 = pd.read_parquet( path + "ITM_DSC_ATTRIBUTES_NEW_parquet.gzip")
df_file3.columns
# Out:
# Index(['ITM_ID', 'GTIN_NO', 'GTIN_NAM', 'CON_UNT_ITM_DSC', 'DSP_UNT_ITM_DSC',
#        'PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC', 'SUBCOM_DSC',
#        'TAG_DSC', 'RCT_DSC', 'ITM_LVL_DSC', 'GRP_LVL_DSC',
#        'NET_CONT_EQV_QY_VIP_TO_KRG_QY', 'NET_CONT_EQV_UOM_VIP_TO_KRG_UOM',
#        'GTIN_HGT_OVD', 'GTIN_LTH_OVD', 'GTIN_WTH_OVD', 'GRS_WGT_OVD',
#        'GTIN_NET_WGT_OVD', 'MIN_DAYS_OF_SHF_LIF_AT_WHS_DAYS', 'TPT_CLS_CD',
#        'TPT_CLS_VLU', 'MAX_DAYS_OF_SHF_LIF_AT_WHS_DTB_CET_DAYS',
#        'TYP_OF_LBL_CD', 'TYP_OF_LBL_VLU', 'SIZ_CD', 'SIZ_CD_VLU', 'SIZ_QY',
#        'IS_EDBL_CD', 'IS_EDBL_VLU', 'VND_ECOM_DSC', 'KRG_OWN_ECOM_DSC'],
#       dtype='object')

# %%
df_file3.shape
# Out:
# (4937400, 34)

# %%
#4 CLS_SPC_ATB_Full_062623_parquet.gzip
df_file4 = pd.read_parquet( path + "ITM_DSC_ATTRIBUTES_NEW_parquet.gzip")
df_file4.columns
# Out:
# Index(['ITM_ID', 'GTIN_NO', 'GTIN_NAM', 'CON_UNT_ITM_DSC', 'DSP_UNT_ITM_DSC',
#        'PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC', 'SUBCOM_DSC',
#        'TAG_DSC', 'RCT_DSC', 'ITM_LVL_DSC', 'GRP_LVL_DSC',
#        'NET_CONT_EQV_QY_VIP_TO_KRG_QY', 'NET_CONT_EQV_UOM_VIP_TO_KRG_UOM',
#        'GTIN_HGT_OVD', 'GTIN_LTH_OVD', 'GTIN_WTH_OVD', 'GRS_WGT_OVD',
#        'GTIN_NET_WGT_OVD', 'MIN_DAYS_OF_SHF_LIF_AT_WHS_DAYS', 'TPT_CLS_CD',
#        'TPT_CLS_VLU', 'MAX_DAYS_OF_SHF_LIF_AT_WHS_DTB_CET_DAYS',
#        'TYP_OF_LBL_CD', 'TYP_OF_LBL_VLU', 'SIZ_CD', 'SIZ_CD_VLU', 'SIZ_QY',
#        'IS_EDBL_CD', 'IS_EDBL_VLU', 'VND_ECOM_DSC', 'KRG_OWN_ECOM_DSC'],
#       dtype='object')

# %%
file = "l1_l2_unlabel_pred_map_W2vec_083123.csv"
df_un_label  = pd.read_csv(DBFR + file )
df_un_label.shape
# Out:
# (5012719, 16)

# %%
df_un_label.rename( columns = {"Accuracy":"Scores"}, inplace = True) 
df_un_label.columns
# Out:
# Index(['ITM_ID', 'GTIN', 'PMY_DPT_CD', 'PMY_DPT_DSC', 'REC_DPT_CD',
#        'REC_DPT_DSC', 'DPT_CD', 'DPT_DSC', 'COM_CD', 'COM_DSC', 'SUBCOM_CD',
#        'SUBCOM_DSC', 'VND_ECOM_DSC', 'ITEM_SUBCOM_text', 'Predict', 'Scores'],
#       dtype='object')

# %%
#3

# %%
df_un_label.to_csv(DBFR + file , index=None)

# %%
def proc_unlabelled_data():
    unlabelled_file   = 'Syndigo_Levels_L1_L2_L3.xlsx'
    df_unlabel  = pd.read_csv( path + unlabelled_file, compression="zip") # (1,048,575, 22)
    print(f'df_unlabel.shape {df_unlabel.shape} for unlabelled_file {unlabelled_file}')
    print(f'df_unlabel.columns \n {df_unlabel.columns}')
    print(f'df_unlabel.info() {df_unlabel.info() }')
    
    s_unlabel = df_unlabel.groupby(['Level1','Level2'])['L2_Scores'].median() 
    df_unlabel_median = pd.DataFrame (s_unlabel, columns= ['Median']).reset_index()
    print(f'df_unlabel_median.shape  {df_unlabel_median.shape}' )
    print(f'df_unlabel_mediav.info()  {df_unlabel_median.info()}' ) 
    print(f'df_unlabel_mediav.head()  {df_unlabel_median.head()}' ) 
    return df_unlabel_median

# %%
import numpy as np
import pandas as pd 

pd.options.display.float_format = '{:,.4f}'.format
pd.set_option('display.max_columns', None) 
pd.set_option("display.max_rows", None)
path = 'C:\\users\\iny2819\\kroger\\Data\\'

# %%
df_zip = pd.read_csv( path + "Syndigo_Levels_L1_L2_L3.zip", compression="zip")
df_zip.shape
# Out:
# (5211106, 22)

# %%
df_unlabel = df_zip.copy()

# %%
df_unlabel.shape
# Out:
# (5211106, 22)

# %%
df_unlabel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5211106 entries, 0 to 5211105
# Data columns (total 22 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   VND_ECOM_DSC  object
#  1   Level1        object
#  2   L1_Scores     float64
#  3   Level2        object
#  4   L2_Scores     float64
#  5   GTIN          float64
#  6   PMY_DPT_CD    float64
#  7   PMY_DPT_DSC   object
#  8   REC_DPT_CD    float64
#  9   REC_DPT_DSC   object
#  10  DPT_CD        float64
#  11  DPT_DSC       object
#  12  COM_CD        float64
#  13  COM_DSC       object
#  14  SUBCOM_CD     float64
#  15  SUBCOM_DSC    object
#  16  ITM_ID        float64
#  17  L1_Percent    object
#  18  L2_Percent    object
#  19  L2_Flag       int64
#  20  Score         float64
#  21  Level3        object
# dtypes: float64(10), int64(1), object(11)
# memory usage: 874.7+ MB

# %%
df_unlabel.groupby(['Level1','Level2'])['L2_Scores'].median()  #pandas.core.series.Series
# Out:
# Level1                                    Level2
# Agricultural Equipment                    Tires                                                      0.5418
# Apparel                                   Clothing                                                   0.6176
#                                           Footwear                                                   0.3519
#                                           Personal Accessories                                       0.4993
#                                           Safety Apparel                                             0.3691
# Appliances                                Small Appliances                                           0.9305
# Arts & Crafts                             Craft Kits                                                 0.2529
#                                           Drawing Tools                                              0.2630
# ...

# %%
s_unlabel = df_unlabel.groupby(['Level1','Level2'])['L2_Scores'].median()  # len = 157; pandas.core.series.Series

# %%
len(s_unlabel)
# Out:
# 157

# %%
#df_unlabel_medium = pd.DataFrame (s_unlabel, columns= ['Medium']).reset_index()
                         
#df_medium = pd.DataFrame (s_unlabel, columns= ['Medium'])
df_medium = pd.DataFrame (s_unlabel).rename(columns= {'L2_Scores':'Medium' }).reset_index()
#df_syn_L1_l2 = pd.DataFrame(s_syn,  columns=["Count"]).reset_index()

# %%
df_medium = df_medium_bkup.copy()
'''
  df_unlabled_medium_cnt_L = df_unlabled_medium_cnt_L
'''
df_cnt = df_medium_cnt
df_unlabled_medium_cnt_L = df_medium.merge(df_cnt, on = ['Level1', 'Level2'], how ='left' )  # (157, 4)
df_unlabled_medium_cnt_R = df_medium.merge(df_cnt, on = ['Level1', 'Level2'], how ='right' ) # (157, 4)

# %%
path = 'C:\\users\\iny2819\\kroger\\Data\\'
df_unlabled_medium_cnt_L.to_excel(path + "df_unlabled_medium_cnt_L.xlsx",index=None, sheet_name= 'L')
df_unlabled_medium_cnt_R.to_excel(path + "df_unlabled_medium_cnt_R.xlsx",index=None, sheet_name= 'R')

# %%
df_cnt.sort_values(['Level1', 'Level2'], inplace = True)
df_cnt.head(10)
# Out:
#                      Level1                   Level2   Count
# 136  Agricultural Equipment                    Tires      25
# 1                   Apparel                 Clothing  561297
# 96                  Apparel                 Footwear     599
# 51                  Apparel     Personal Accessories    9230
# 122                 Apparel           Safety Apparel      85
# 144              Appliances      Parts & Accessories       7
# 40               Appliances         Small Appliances   21406
# 52            Arts & Crafts               Craft Kits    8870
# 20            Arts & Crafts            Drawing Tools   66271
# 125           Arts & Crafts  Needlework & Toy Making      82

# %%
df_medium.head(10)
# Out:
#                    Level1                   Level2  Medium
# 0  Agricultural Equipment                    Tires  0.5588
# 1                 Apparel                 Clothing  0.7098
# 2                 Apparel                 Footwear  0.8650
# 3                 Apparel     Personal Accessories  0.4995
# 4                 Apparel           Safety Apparel  0.4328
# 5              Appliances      Parts & Accessories  0.5965
# 6              Appliances         Small Appliances  0.9409
# 7           Arts & Crafts               Craft Kits  0.2542
# 8           Arts & Crafts            Drawing Tools  0.2622
# 9           Arts & Crafts  Needlework & Toy Making  0.2913

# %%
df_unlabled_medium_cnt_L.head
# Out:
# <bound method NDFrame.head of                                        Level1  \
# 0                      Agricultural Equipment
# 1                                     Apparel
# 2                                     Apparel
# 3                                     Apparel
# 4                                     Apparel
# 5                                  Appliances
# 6                                  Appliances
# 7                               Arts & Crafts
# 8                               Arts & Crafts
# 9                               Arts & Crafts
# 10                              Arts & Crafts
# 11                              Arts & Crafts
# 12                              Arts & Crafts
# 13                              Arts & Crafts
# 14                              Arts & Crafts
# 15                              Arts & Crafts
# 16                                 Automotive
# 17                                 Automotive
# 18                                 Automotive
# ...

# %%
df_unlabled_medium_cnt_R.head
# Out:
# <bound method NDFrame.head of                                        Level1  \
# 0                      Agricultural Equipment
# 1                                     Apparel
# 2                                     Apparel
# 3                                     Apparel
# 4                                     Apparel
# 5                                  Appliances
# 6                                  Appliances
# 7                               Arts & Crafts
# 8                               Arts & Crafts
# 9                               Arts & Crafts
# 10                              Arts & Crafts
# 11                              Arts & Crafts
# 12                              Arts & Crafts
# 13                              Arts & Crafts
# 14                              Arts & Crafts
# 15                              Arts & Crafts
# 16                                 Automotive
# 17                                 Automotive
# 18                                 Automotive
# ...

# %%
df_medium.head()
# Out:
#                    Level1                Level2  Medium
# 0  Agricultural Equipment                 Tires  0.5588
# 1                 Apparel              Clothing  0.7098
# 2                 Apparel              Footwear  0.8650
# 3                 Apparel  Personal Accessories  0.4995
# 4                 Apparel        Safety Apparel  0.4328

# %%
df_nml_cnt = pd.DataFrame(df_unlabel[['Level1', 'Level2']].value_counts(dropna = True,normalize = True), columns=["Nomalized Count"]).reset_index() # (157,3)

# %%
df_nml_cnt.sort_values(['Level1', 'Level2'], inplace = True)

# %%
df_nml_cnt.head(20)
# Out:
#                      Level1                        Level2  Nomalized Count
# 136  Agricultural Equipment                         Tires           0.0000
# 1                   Apparel                      Clothing           0.1077
# 96                  Apparel                      Footwear           0.0001
# 51                  Apparel          Personal Accessories           0.0018
# 122                 Apparel                Safety Apparel           0.0000
# 144              Appliances           Parts & Accessories           0.0000
# 40               Appliances              Small Appliances           0.0041
# 52            Arts & Crafts                    Craft Kits           0.0017
# 20            Arts & Crafts                 Drawing Tools           0.0127
# 125           Arts & Crafts       Needlework & Toy Making           0.0000
# 74            Arts & Crafts            Painting & Drawing           0.0005
# ...

# %%
df_nml_cnt['Nomalized Count'].sum()
# Out:
# 1.0000000000000002

# %%
df_medium_bkup = df_medium_

# %%
df_medium['unlabeled Count'] = df_medium_cnt['Count']

# %%
df_medium.head()
# Out:
#                    Level1                Level2  Medium  unlabeled Count
# 0  Agricultural Equipment                 Tires  0.5588           779782
# 1                 Apparel              Clothing  0.7098           561297
# 2                 Apparel              Footwear  0.8650           332846
# 3                 Apparel  Personal Accessories  0.4995           304254
# 4                 Apparel        Safety Apparel  0.4328           289439

# %%
df_medium[['Level1', 'Level2']].value_counts(dropna = True)
# Out:
# Level1                                    Level2
# Agricultural Equipment                    Tires                                                       1
# Apparel                                   Clothing                                                    1
# Office Supplies                           Office Fasteners                                            1
#                                           Greeting Cards & Gift Packaging                             1
#                                           Filing & Storage                                            1
# Marine                                    Heating, Ventilation, & Air Conditioning                    1
# Livestock & Pet Supplies                  Pet Supplies                                                1
# Lighting & Fans                           Light Bulbs                                                 1
# ...

# %%
path_file = path + 'Syndigo_GTIN_Mapping_060723.xlsx'
#syndigo_mapped = pd.read_csv('/dbfs/FileStore/tables/DATA_SCIENCE/Syndigo_GTIN_Mapping_060723.csv')
syndigo_mapped  = pd.read_excel(path_file)
#syndigo_concat  = pd.read_csv(path + 'Syndiago Parts 1-2-3-4-5 matches w taxonomy classification.csv')

# %%
#tmp_syn = syndigo_mapped [['Level 1', 'Level 2']].value_counts(dropna = True, ascending = True)  
s_syn = syndigo_mapped [['Level 1', 'Level 2']].value_counts(dropna = True,sort = False)

# %%
s_syn
# Out:
# Level 1                                   Level 2
# Apparel                                   Clothing                                                       27
#                                           Footwear                                                       78
#                                           Personal Accessories                                           66
#                                           Safety Apparel                                                 16
# Appliances                                Microwaves                                                      2
#                                           Parts & Accessories                                             7
#                                           Ranges                                                          1
#                                           Small Appliances                                              183
# ...

# %%
df_syn_L1_l2 = pd.DataFrame(s_syn,  columns=["Count"]).reset_index()

# %%
df_syn_L1_l2.head()
# Out:
#       Level 1               Level 2  Count
# 0     Apparel              Clothing     27
# 1     Apparel              Footwear     78
# 2     Apparel  Personal Accessories     66
# 3     Apparel        Safety Apparel     16
# 4  Appliances            Microwaves      2

# %%
df_syn_L1_l2.shape
# Out:
# (207, 3)

# %%
df_mlrf = pd.read_excel( path + "Beer_Wine_Spirits_ML_RF_val.xlsx")  # UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf8 in position 14: invalid start byte

# %%
df_mlrfdf_mlrf

# %%
temp = df_mlrf [['PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC','SUBCOM_DSC']].value_counts() # pandas.core.series.Series

# %%
# Using reset_index() to set index into column

df_temp = pd.DataFrame(temp,  columns=["Count"]).reset_index()

# %%
df_temp.head()
# Out:
#   PMY_DPT_DSC REC_DPT_DSC  DPT_DSC            COM_DSC  \
# 0     GROCERY      LIQUOR     BEER  CRAFT/MICRO BEERS
# 1     GROCERY      LIQUOR     WINE         TABLE WINE
# 2     GROCERY      LIQUOR     WINE         TABLE WINE
# 3     GROCERY      LIQUOR     WINE         TABLE WINE
# 4     GROCERY      LIQUOR  SPIRITS    N. AMER WHISKEY
#
#                          SUBCOM_DSC  Count
# 0              LOCAL/REGIONAL CRAFT  12597
# 1     750ML RED PREM WINES $8-14.99   6736
# 2  750ML RED LUXURY WINES ABOVE $15   6346
# 3   750ML WHITE PREM WINES $8-14.99   3869
# 4                BOURBON/TN WHISKEY   3855

# %%
temp.index
# Out:
# MultiIndex([('GROCERY',  'LIQUOR',           'BEER', ...),
#             ('GROCERY',  'LIQUOR',           'WINE', ...),
#             ('GROCERY',  'LIQUOR',           'WINE', ...),
#             ('GROCERY',  'LIQUOR',           'WINE', ...),
#             ('GROCERY',  'LIQUOR',        'SPIRITS', ...),
#             ('GROCERY',  'LIQUOR',           'WINE', ...),
#             ('GROCERY',  'LIQUOR',           'WINE', ...),
#             ('GROCERY',  'LIQUOR',           'BEER', ...),
#             ('GROCERY',  'LIQUOR',        'SPIRITS', ...),
#             ('GROCERY',  'LIQUOR',        'SPIRITS', ...),
#             ...
#             ('DRUG/GM',     'HBC',         'HEALTH', ...),
#             ('DRUG/GM',     'HBC',         'HEALTH', ...),
#             ('GROCERY', 'GROCERY', 'FROZEN GROCERY', ...),
#             ('GROCERY', 'GROCERY',            'PET', ...),
#             ('DRUG/GM',     'HBC',         'HEALTH', ...),
#             ('DRUG/GM',     'HBC',  'PERSONAL CARE', ...),
# ...

# %%
df = df_temp
df_bkup = df.copy()

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns ={'0': 'count'}, inplace = True )  #NW

# %%
df.rename(columns ={'count': '0'}, inplace = True )  # NW

# %%
df.head()
# Out:
#   PMY_DPT_DSC REC_DPT_DSC  DPT_DSC            COM_DSC  \
# 0     GROCERY      LIQUOR     BEER  CRAFT/MICRO BEERS
# 1     GROCERY      LIQUOR     WINE         TABLE WINE
# 2     GROCERY      LIQUOR     WINE         TABLE WINE
# 3     GROCERY      LIQUOR     WINE         TABLE WINE
# 4     GROCERY      LIQUOR  SPIRITS    N. AMER WHISKEY
#
#                          SUBCOM_DSC      0
# 0              LOCAL/REGIONAL CRAFT  12597
# 1     750ML RED PREM WINES $8-14.99   6736
# 2  750ML RED LUXURY WINES ABOVE $15   6346
# 3   750ML WHITE PREM WINES $8-14.99   3869
# 4                BOURBON/TN WHISKEY   3855

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PMY_DPT_DSC  293 non-null    object
#  1   REC_DPT_DSC  293 non-null    object
#  2   DPT_DSC      293 non-null    object
#  3   COM_DSC      293 non-null    object
#  4   SUBCOM_DSC   293 non-null    object
#  5   0            293 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 13.9+ KB

# %%
# Below are the quick examples.

# Create a new column with index values
df['index_column'] = df.index

# Using reset_index() to set index into column
df2=df.reset_index()

# Using reset_index, inplace=True
df.reset_index(inplace=True)

# When you have multiple index 
# Specify which index you wanted to set to column
df.reset_index(inplace=True, level=['Fee'])

# Preserve Index as-is and add one index as column
df2 = df.assign(Fee=df.index.get_level_values('Fee'))

# Preserve Index as-is and add one index as column
# Using assign operator.
df['Fee'] = df.index.get_level_values('Fee')

# %%
df_temp = df_temp.rename_axis('index1').reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_temp = df_temp.rename_axis('index1').reset_index()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:347, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     345 @wraps(func)
#     346 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 347     return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df_mlrf [['PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC','SUBCOM_DSC']].value_counts()[:20]
# Out:
# PMY_DPT_DSC  REC_DPT_DSC  DPT_DSC  COM_DSC                  SUBCOM_DSC
# GROCERY      LIQUOR       BEER     CRAFT/MICRO BEERS        LOCAL/REGIONAL CRAFT                    12597
#                           WINE     TABLE WINE               750ML RED PREM WINES $8-14.99            6736
#                                                             750ML RED LUXURY WINES ABOVE $15         6346
#                                                             750ML WHITE PREM WINES $8-14.99          3869
#                           SPIRITS  N. AMER WHISKEY          BOURBON/TN WHISKEY                       3855
#                           WINE     MISC WINE                ALL OTHERS                               3506
#                                    TABLE WINE               750ML WHITE LUXURY WINES ABOVE $15       2341
#                           BEER     SINGLES                  CRAFT SINGLE                             2193
# ...

# %%
type(df_mlrf [['PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC','SUBCOM_DSC']].value_counts())
# Out:
# pandas.core.series.Series

# %%
ser = df_mlrf [['PMY_DPT_DSC', 'REC_DPT_DSC', 'DPT_DSC', 'COM_DSC','SUBCOM_DSC']].value_counts() # pandas.core.series.Series

# %%
ser = ser.sort_index()  # 293

# %%
print(ser[0:100])
# Out:
# PMY_DPT_DSC  REC_DPT_DSC    DPT_DSC          COM_DSC                   SUBCOM_DSC
# DELI/BAKE    DELI PACKAGED  PACKAGED DELI    READY TO HEAT PASTA       CUT                                             2
# DRUG/GM      GM             ACCESSORIES      HANDBAGS/BAGS             SEASONAL                                        4
#                             DOMESTICS        BATH                      BATH ACCESSORIES                                1
#                             FURN/HOME DEC    CANDLES AND GIFTWARE      ESSENTIAL OILS/DIFFUSERS/INCENSE                2
#                                                                        JAR CANDLES                                     4
#                                                                        WARMERS/WAX MELTS/FLAMELESS                    15
#                                              HOME ACCESSORIES          DECORATIVE ACCENTS                            365
# ...

# %%
len(ser)
# Out:
# 293

# %%
print(ser[100:151])
# Out:
# PMY_DPT_DSC  REC_DPT_DSC  DPT_DSC          COM_DSC                         SUBCOM_DSC
# DRUG/GM      HBC          PERSONAL CARE    SHAVE                           MALE REFILLS                                3
#                                            SOAP - LIQUID & BAR             BAR SOAP                                    1
#                           TOBACCO          CIGARS                          CIGARS                                      5
#                                            SMOKING TOBACCO                 SMOKING TOBACCO                             8
#                                            TOBACCO SET EXEMPT              CIGARETTE PARAPHERNALIA                     3
# GROCERY      GROCERY      CKY/CRKR/SNK     BAG SNACKS                      PORK SKINS/CRACKLINS                        1
#                                            RICE CAKES                      MINI-CAKES                                  3
# ...

# %%
print(ser[151:251])
# Out:
# PMY_DPT_DSC  REC_DPT_DSC  DPT_DSC         COM_DSC                         SUBCOM_DSC
# GROCERY      GROCERY      GROC-ALL OTHER  MIXERS                          COCKTAIL MIXES-FLUID:ADD LIQ                      98
#                                                                           MARGARITA SALT/SUGAR/MISC                         23
#                                                                           MIXERS(TONIC WATER/GNGR ALE)UNFLVRD ONLY           3
#                                                                           MIXERS(TONIC WTR/GNGR ALE)FLAVORED ONLY           16
#                                           MOLASSES/SYRUPS/PANCAKE MIXES   MOLASSES & SYRUPS                                  3
#                                           PASTA & PIZZA SAUCE             MAINSTREAM                                         1
#                                                                           PREMIUM                                           11
# ...

# %%
print(ser[251:293])
# Out:
# PMY_DPT_DSC  REC_DPT_DSC    DPT_DSC        COM_DSC                        SUBCOM_DSC
# GROCERY      LIQUOR         WINE           MISC WINE                      NON ALCOHOLIC                              30
#                                                                           POUCHES                                    63
#                                            SPARKLING WINE                 SPARKLING LUXURY ABOVE $15                853
#                                                                           SPARKLING PREM $8-14.99                   744
#                                                                           SPARKLING VALUE $0-$7.99                  205
#                                            TABLE WINE                     1.5L WINES                               1647
#                                                                           3L BOX WINES                              429
# ...

# %%
dic_L1 = {'LivestockPetSupplies.csv'    : 'Livestock & Pet Supplies',     
          'HomeVenueDecoration.xlsx'    : 'Home & Venue Decoration', 
          'GardeningOutdoors.csv'       : 'Gardening & Outdoors',       
          'ToysGamesHobbies.csv'        : 'Toys / Games / Hobbies',        
          'KitchenBathroom.xlsx'        : 'Kitchen & Bathroom',
          'F&B (1).xlsx'                : 'Food / Beverages'
         }

# %%
lower('BASE FLAVOR CATEGORIES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 lower('BASE FLAVOR CATEGORIES')
#
# NameError: name 'lower' is not defined

# %%
' PRIVATE SELECTION'.lower()
# Out:
# ' private selection'
