# %%
import pandas as pd

# %%
import os
from openai import AzureOpenAI
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:92, in _tempfile(reader, suffix, _os_remove)
#      91 try:
# ---> 92     os.write(fd, reader())
#      93     os.close(fd)
#
# File ~\AppData\Local\anaconda3\lib\importlib\abc.py:371, in Traversable.read_bytes(self)
#     368 """
#     369 Read contents of self as bytes
#     370 """
# --> 371 with self.open('rb') as strm:
#     372     return strm.read()
#
# File ~\AppData\Local\anaconda3\lib\importlib\_adapters.py:54, in DegenerateFiles.Path.open(self, mode, *args, **kwargs)
#      53 def open(self, mode='rb', *args, **kwargs):
# ---> 54     raise ValueError()
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from openai import AzureOpenAI
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\__init__.py:19
#      15     import aiohttp
#      17     del sys.modules["pkg_resources"]
# ---> 19 from openai.api_resources import (
#      20     Audio,
#      21     ChatCompletion,
#      22     Completion,
#      23     Customer,
#      24     Deployment,
#      25     Edit,
#      26     Embedding,
#      27     Engine,
#      28     ErrorObject,
#      29     File,
#      30     FineTune,
#      31     FineTuningJob,
#      32     Image,
#      33     Model,
#      34     Moderation,
#      35 )
#      36 from openai.error import APIError, InvalidRequestError, OpenAIError
#      37 from openai.version import VERSION
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\__init__.py:1
# ----> 1 from openai.api_resources.audio import Audio  # noqa: F401
#       2 from openai.api_resources.chat_completion import ChatCompletion  # noqa: F401
#       3 from openai.api_resources.completion import Completion  # noqa: F401
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\audio.py:4
#       1 from typing import Any, List
#       3 import openai
# ----> 4 from openai import api_requestor, util
#       5 from openai.api_resources.abstract import APIResource
#       8 class Audio(APIResource):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_requestor.py:24
#      21 from urllib.parse import urlencode, urlsplit, urlunsplit
#      23 import aiohttp
# ---> 24 import requests
#      26 if sys.version_info >= (3, 8):
#      27     from typing import Literal
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\__init__.py:147
#     144 import logging
#     145 from logging import NullHandler
# --> 147 from . import packages, utils
#     148 from .__version__ import (
#     149     __author__,
#     150     __author_email__,
#    (...)
#     158     __version__,
#     159 )
#     160 from .api import delete, get, head, options, patch, post, put, request
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\utils.py:24
#      20 from collections import OrderedDict
#      22 from urllib3.util import make_headers, parse_url
# ---> 24 from . import certs
#      25 from .__version__ import __version__
#      27 # to_native_string is unused here, but imported here for backwards compatibility
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\certs.py:14
#       1 #!/usr/bin/env python
#       3 """
#       4 requests.certs
#       5 ~~~~~~~~~~~~~~
#    (...)
#      12 packaged CA bundle.
#      13 """
# ---> 14 from certifi import where
#      16 if __name__ == "__main__":
#      17     print(where())
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:177, in _ImportHookChainedLoader._exec_module(self, module)
#     175 def _exec_module(self, module):
#     176     self.loader.exec_module(module)
# --> 177     notify_module_loaded(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\decorators.py:470, in synchronized.<locals>._synchronized(wrapped, instance, args, kwargs)
#     464 @decorator
#     465 def _synchronized(wrapped, instance, args, kwargs):
#     466     # Execute the wrapped function while the original supplied
#     467     # lock is held.
#     469     with lock:
# --> 470         return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:136, in notify_module_loaded(module)
#     133 _post_import_hooks[name] = []
#     135 for hook in hooks:
# --> 136     hook(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi_win32\wrapt_certifi.py:20, in apply_patches(certifi)
#      18 certifi_where = certifi.where
#      19 import certifi_win32.wincerts
# ---> 20 certifi_win32.wincerts.CERTIFI_PEM = certifi.where()
#      22 # Wrap the certify.where function
#      23 wrapt.wrap_function_wrapper(certifi, 'where', wrap_where)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi\core.py:72, in where()
#      59 if _CACERT_PATH is None:
#      60     # This is slightly janky, the importlib.resources API wants you
#      61     # to manage the cleanup of this file, so it doesn't actually
#    (...)
#      69     # it will do the cleanup whenever it gets garbage collected, so
#      70     # we will also store that at the global level as well.
#      71     _CACERT_CTX = get_path("certifi", "cacert.pem")
# ---> 72     _CACERT_PATH = str(_CACERT_CTX.__enter__())
#      74 return _CACERT_PATH
#
# File ~\AppData\Local\anaconda3\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:98, in _tempfile(reader, suffix, _os_remove)
#      96 finally:
#      97     try:
# ---> 98         _os_remove(raw_path)
#      99     except FileNotFoundError:
#     100         pass
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\iny2819\\AppData\\Local\\Temp\\tmpgfmh247k'

# %%
import openai
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:92, in _tempfile(reader, suffix, _os_remove)
#      91 try:
# ---> 92     os.write(fd, reader())
#      93     os.close(fd)
#
# File ~\AppData\Local\anaconda3\lib\importlib\abc.py:371, in Traversable.read_bytes(self)
#     368 """
#     369 Read contents of self as bytes
#     370 """
# --> 371 with self.open('rb') as strm:
#     372     return strm.read()
#
# File ~\AppData\Local\anaconda3\lib\importlib\_adapters.py:54, in DegenerateFiles.Path.open(self, mode, *args, **kwargs)
#      53 def open(self, mode='rb', *args, **kwargs):
# ---> 54     raise ValueError()
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import openai
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\__init__.py:19
#      15     import aiohttp
#      17     del sys.modules["pkg_resources"]
# ---> 19 from openai.api_resources import (
#      20     Audio,
#      21     ChatCompletion,
#      22     Completion,
#      23     Customer,
#      24     Deployment,
#      25     Edit,
#      26     Embedding,
#      27     Engine,
#      28     ErrorObject,
#      29     File,
#      30     FineTune,
#      31     FineTuningJob,
#      32     Image,
#      33     Model,
#      34     Moderation,
#      35 )
#      36 from openai.error import APIError, InvalidRequestError, OpenAIError
#      37 from openai.version import VERSION
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\__init__.py:1
# ----> 1 from openai.api_resources.audio import Audio  # noqa: F401
#       2 from openai.api_resources.chat_completion import ChatCompletion  # noqa: F401
#       3 from openai.api_resources.completion import Completion  # noqa: F401
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\audio.py:4
#       1 from typing import Any, List
#       3 import openai
# ----> 4 from openai import api_requestor, util
#       5 from openai.api_resources.abstract import APIResource
#       8 class Audio(APIResource):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_requestor.py:24
#      21 from urllib.parse import urlencode, urlsplit, urlunsplit
#      23 import aiohttp
# ---> 24 import requests
#      26 if sys.version_info >= (3, 8):
#      27     from typing import Literal
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\__init__.py:147
#     144 import logging
#     145 from logging import NullHandler
# --> 147 from . import packages, utils
#     148 from .__version__ import (
#     149     __author__,
#     150     __author_email__,
#    (...)
#     158     __version__,
#     159 )
#     160 from .api import delete, get, head, options, patch, post, put, request
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\utils.py:24
#      20 from collections import OrderedDict
#      22 from urllib3.util import make_headers, parse_url
# ---> 24 from . import certs
#      25 from .__version__ import __version__
#      27 # to_native_string is unused here, but imported here for backwards compatibility
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\certs.py:14
#       1 #!/usr/bin/env python
#       3 """
#       4 requests.certs
#       5 ~~~~~~~~~~~~~~
#    (...)
#      12 packaged CA bundle.
#      13 """
# ---> 14 from certifi import where
#      16 if __name__ == "__main__":
#      17     print(where())
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:177, in _ImportHookChainedLoader._exec_module(self, module)
#     175 def _exec_module(self, module):
#     176     self.loader.exec_module(module)
# --> 177     notify_module_loaded(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\decorators.py:470, in synchronized.<locals>._synchronized(wrapped, instance, args, kwargs)
#     464 @decorator
#     465 def _synchronized(wrapped, instance, args, kwargs):
#     466     # Execute the wrapped function while the original supplied
#     467     # lock is held.
#     469     with lock:
# --> 470         return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:136, in notify_module_loaded(module)
#     133 _post_import_hooks[name] = []
#     135 for hook in hooks:
# --> 136     hook(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi_win32\wrapt_certifi.py:20, in apply_patches(certifi)
#      18 certifi_where = certifi.where
#      19 import certifi_win32.wincerts
# ---> 20 certifi_win32.wincerts.CERTIFI_PEM = certifi.where()
#      22 # Wrap the certify.where function
#      23 wrapt.wrap_function_wrapper(certifi, 'where', wrap_where)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi\core.py:72, in where()
#      59 if _CACERT_PATH is None:
#      60     # This is slightly janky, the importlib.resources API wants you
#      61     # to manage the cleanup of this file, so it doesn't actually
#    (...)
#      69     # it will do the cleanup whenever it gets garbage collected, so
#      70     # we will also store that at the global level as well.
#      71     _CACERT_CTX = get_path("certifi", "cacert.pem")
# ---> 72     _CACERT_PATH = str(_CACERT_CTX.__enter__())
#      74 return _CACERT_PATH
#
# File ~\AppData\Local\anaconda3\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:98, in _tempfile(reader, suffix, _os_remove)
#      96 finally:
#      97     try:
# ---> 98         _os_remove(raw_path)
#      99     except FileNotFoundError:
#     100         pass
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\iny2819\\AppData\\Local\\Temp\\tmpn5lxo60s'

# %%
#https://eastus2.api.cognitive.microsoft.com/
#Note: The openai-python library support for Azure OpenAI is in preview.
#Note: This code sample requires OpenAI Python library version 0.28.1 or lower.
# replace  engine="acadeployai" with 'acaopenai'

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:92, in _tempfile(reader, suffix, _os_remove)
#      91 try:
# ---> 92     os.write(fd, reader())
#      93     os.close(fd)
#
# File ~\AppData\Local\anaconda3\lib\importlib\abc.py:371, in Traversable.read_bytes(self)
#     368 """
#     369 Read contents of self as bytes
#     370 """
# --> 371 with self.open('rb') as strm:
#     372     return strm.read()
#
# File ~\AppData\Local\anaconda3\lib\importlib\_adapters.py:54, in DegenerateFiles.Path.open(self, mode, *args, **kwargs)
#      53 def open(self, mode='rb', *args, **kwargs):
# ---> 54     raise ValueError()
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 7
#       1 #https://eastus2.api.cognitive.microsoft.com/
#       2 #Note: The openai-python library support for Azure OpenAI is in preview.
#       3 #Note: This code sample requires OpenAI Python library version 0.28.1 or lower.
#       4 # replace  engine="acadeployai" with 'acaopenai'
#       6 import os
# ----> 7 import openai
#       9 openai.api_key = os.getenv("OPENAI_API_KEY")
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\__init__.py:19
#      15     import aiohttp
#      17     del sys.modules["pkg_resources"]
# ---> 19 from openai.api_resources import (
#      20     Audio,
#      21     ChatCompletion,
#      22     Completion,
#      23     Customer,
#      24     Deployment,
#      25     Edit,
#      26     Embedding,
#      27     Engine,
#      28     ErrorObject,
#      29     File,
#      30     FineTune,
#      31     FineTuningJob,
#      32     Image,
#      33     Model,
#      34     Moderation,
#      35 )
#      36 from openai.error import APIError, InvalidRequestError, OpenAIError
#      37 from openai.version import VERSION
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\__init__.py:1
# ----> 1 from openai.api_resources.audio import Audio  # noqa: F401
#       2 from openai.api_resources.chat_completion import ChatCompletion  # noqa: F401
#       3 from openai.api_resources.completion import Completion  # noqa: F401
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_resources\audio.py:4
#       1 from typing import Any, List
#       3 import openai
# ----> 4 from openai import api_requestor, util
#       5 from openai.api_resources.abstract import APIResource
#       8 class Audio(APIResource):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\openai\api_requestor.py:24
#      21 from urllib.parse import urlencode, urlsplit, urlunsplit
#      23 import aiohttp
# ---> 24 import requests
#      26 if sys.version_info >= (3, 8):
#      27     from typing import Literal
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\__init__.py:147
#     144 import logging
#     145 from logging import NullHandler
# --> 147 from . import packages, utils
#     148 from .__version__ import (
#     149     __author__,
#     150     __author_email__,
#    (...)
#     158     __version__,
#     159 )
#     160 from .api import delete, get, head, options, patch, post, put, request
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\utils.py:24
#      20 from collections import OrderedDict
#      22 from urllib3.util import make_headers, parse_url
# ---> 24 from . import certs
#      25 from .__version__ import __version__
#      27 # to_native_string is unused here, but imported here for backwards compatibility
#
# File ~\AppData\Local\anaconda3\lib\site-packages\requests\certs.py:14
#       1 #!/usr/bin/env python
#       3 """
#       4 requests.certs
#       5 ~~~~~~~~~~~~~~
#    (...)
#      12 packaged CA bundle.
#      13 """
# ---> 14 from certifi import where
#      16 if __name__ == "__main__":
#      17     print(where())
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:177, in _ImportHookChainedLoader._exec_module(self, module)
#     175 def _exec_module(self, module):
#     176     self.loader.exec_module(module)
# --> 177     notify_module_loaded(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\decorators.py:470, in synchronized.<locals>._synchronized(wrapped, instance, args, kwargs)
#     464 @decorator
#     465 def _synchronized(wrapped, instance, args, kwargs):
#     466     # Execute the wrapped function while the original supplied
#     467     # lock is held.
#     469     with lock:
# --> 470         return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wrapt\importer.py:136, in notify_module_loaded(module)
#     133 _post_import_hooks[name] = []
#     135 for hook in hooks:
# --> 136     hook(module)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi_win32\wrapt_certifi.py:20, in apply_patches(certifi)
#      18 certifi_where = certifi.where
#      19 import certifi_win32.wincerts
# ---> 20 certifi_win32.wincerts.CERTIFI_PEM = certifi.where()
#      22 # Wrap the certify.where function
#      23 wrapt.wrap_function_wrapper(certifi, 'where', wrap_where)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\certifi\core.py:72, in where()
#      59 if _CACERT_PATH is None:
#      60     # This is slightly janky, the importlib.resources API wants you
#      61     # to manage the cleanup of this file, so it doesn't actually
#    (...)
#      69     # it will do the cleanup whenever it gets garbage collected, so
#      70     # we will also store that at the global level as well.
#      71     _CACERT_CTX = get_path("certifi", "cacert.pem")
# ---> 72     _CACERT_PATH = str(_CACERT_CTX.__enter__())
#      74 return _CACERT_PATH
#
# File ~\AppData\Local\anaconda3\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\anaconda3\lib\importlib\_common.py:98, in _tempfile(reader, suffix, _os_remove)
#      96 finally:
#      97     try:
# ---> 98         _os_remove(raw_path)
#      99     except FileNotFoundError:
#     100         pass
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\iny2819\\AppData\\Local\\Temp\\tmp67ocuoh5'

# %%
openai.api_type = "azure"
openai.api_base = "https://eastus2.api.cognitive.microsoft.com/"

openai.api_version = "2023-07-01-preview"


message_text = [{"role":"system","content":"You are an AI assistant that helps people find information."}]

# %%
completion = openai.ChatCompletion.create(
  engine="gpt35modelfn",
  messages = message_text,
  temperature=0.7,
  max_tokens=800,
  top_p=0.95,
  frequency_penalty=0,
  presence_penalty=0,
  stop=None
)

# %%
for _ in range(100):
   completion = openai.ChatCompletion.create(
     engine="gpt35modelfn",
     messages = message_text,
     temperature=0.7,
     max_tokens=800,
     top_p=0.95,
     frequency_penalty=0,
     presence_penalty=0,
     stop=None
   )
