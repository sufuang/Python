# %%
import pandas as pd, numpy as np, re
from rapidfuzz import process, fuzz,utils
np.set_printoptions(threshold=np.inf)

pd.options.display.float_format = '{:20,.2f}'.format 
pd.set_option("display.max_rows", None)
path = 'C:\\users\\iny2819\\Kroger\\Data\\' 
path_atb = path + 'ATB\\'
path_atb_yue = path + 'ATB\\atb_yue\\'

# %%
path_code = 'C:\\users\\iny2819\\kroger\\Code\\'  
f_com_code = path_code + "com_code.py"
exec(compile(open(f_com_code , "rb").read(), f_com_code, 'exec' ))

# %%
import warnings
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
ic_df = pd.read_csv(path_atb + 'ICECREAM_FLAVORS_101223_pipe_delim.csv', sep = '|')
#ic_df = ic_df[ic_df.Flavor == 'OTHER']
ic_df['VND_ECOM_DSC'] = ic_df.VND_ECOM_DSC.fillna('')

# %%
# PRIVATE SELECTION LABELS
pvt_slc = ic_df[ic_df.VND_ECOM_DSC.str.contains('PRIVATE SELECTION') ]

# %%
pvt_slc['SPLIT_ON_ICECREAM'] = pvt_slc.VND_ECOM_DSC.apply(lambda x: x.split('ICE CREAM')[0])
pvt_slc['Flavor'] = pvt_slc.SPLIT_ON_ICECREAM.apply(lambda x: x.split('-')[1].strip(' ') if '-' in x else x.strip(' '))
pvt_slc['Flavor'].value_counts()
pvt_slc.to_csv('Private_Selection_101223.csv', index = None)

# %%
### Source: https://list.fandom.com/wiki/List_of_Ben_%26_Jerry%27s_flavors

# %%
''' Source: https://www.chicagotribune.com/dining/dailymeal-the-complete-list-of-ben-jerry-s-flavors-20180405-story.html


Caramel Chocolate Cheesecake
Chillin' the Roast
Chocolate Shake It
Gimme S'more
Glampfire Trail Mix
One Sweet World
Pecan Sticky Buns
Americone Dream
Banana Split
Blondie Ambition
Boom Chocolatta Cookie Core
Bourbon Pecan Pie
Brewed to Matter
Brownie Batter Core
Cheesecake Brownie
Cherry Garcia
Chocolate Chip Cookie Dough
Chocolate Fudge Brownie
Chocolate Therapy
Chubby Hubby
Chunky Monkey
Cinnamon Buns
Coconuts for Caramel Core
Coffee Toffee Bar Crunch
Coffee, Coffee BuzzBuzzBuzz!
Cookies & Cream Cheesecake Core
Everything But The...
Half Baked
Karamel Sutra Core
Keep Caramel & Cookie On
Milk & Cookies
Mint Chocolate Cookie
New York Super Fudge Chunk
Oat of This Swirled
Peanut Buttah Cookie Core
Peanut Butter Cup
Peanut Butter Fudge Core
Peanut Butter World
Phish Food
Pistachio Pistachio
Pumpkin Cheesecake
Red Velvet Cake
S'mores
Salted Caramel Almond
Salted Caramel Core
Spectacular Speculoos Cookie Core
Strawberry Cheesecake
The Tonight Dough
Triple Caramel Chunk
Truffle Kerfuffle
Urban Bourbon
Vanilla
Vanilla Caramel Fudge
Vanilla Toffee Bar Crunch
'''
bnj_flvs_ct = pd.read_csv( path_atb + 'Ben_Jerrys_Flavors_CTribune.csv').Flavor.str.upper().str.strip(' ').tolist()

# %%
replacements = {'MOCHI': 'MOCHIE',
 ' VAN ': ' VANILLA ',
 ' CHOC ': ' CHOCOLATE ',
   'CHUNCKY' :'CHUNKY',    
   'MARSCAPONE':'MASCARPONE',             
 'NEOPOLITAN': 'NEAPOLITAN',
 ' BDAY ': ' BIRTHDAY ',
 ' CKE ': ' CAKE ',
 ' CRML ': ' CARAMEL ',
   ' VNL ': ' VANILLA ', 
   ' VNLLA ': ' VANILLA ',            
 "'N'": 'AND',
 "'N ": 'AND ',
 " N' ": ' AND ',               
 ' & CREAM': ' AND CREAM',
 ' MNG ': ' MANGO ',
 ' STRWBRY ': ' STRAWBERRY ',
 ' STRWBRRY ': ' STRAWBERRY ' ,
 ' STRWB ': ' STRAWBERRY ' ,  
  ' STRW ': ' STRAWBERRY ',
  ' BLBRY ' : ' BLUEBERRY',
   ' CKIE DGH ': ' COOKIE DOUGH ',         
' FRUITY ': ' FRUIT '  ,
' FRUITS ': ' FRUIT '  ,             
 ' PNUT ': ' PEANUT ',
 ' BTTR ': ' BUTTER ',
 ' PNUT BTR ': ' PEANUT BUTTER ',              
 ' CRM ': ' CREAM ',
 'CREME': 'CREAM',              
 ' CHP ': ' CHIP ',
 ' MNT ': ' MINT ',
 ' MINT CHIP': ' MINT CHOCOLATE CHIP',  
  'COOKIE N CRM': 'COOKIES AND CREAM',
  'CKY N CRM':'COOKIES AND CREAM',
  ' CKIE CRM ': ' COOKIES AND CREAM ',
  'CKIES&CRM'   :'COOKIES AN CREAM',          
  ' PNTBTTR' :'PEANUT BUTTER',
   'PNUT BT' : 'PEANUT BUTTER',   
    ' ALM ' : ' ALMOND ',   
  'ICE CREAM':'ICECREAM',   
   'DOUBLE RAINBOW':'',  
    'MACHIATO':'MACHIATTO',   
     'STRWBRY CHIP':'STRAWBERRY CHIP',
     'PNK GRPFRT':'PINK GRAPEFRUIT',
     'RASP ':'RASPBERRY ' ,       
       'WLD BRY ': 'WILDBERRY ',
      'STRW LMNAD': 'STRAWBERRY LEMONADE',   
     'BLK RASP CHIP': 'BLACK RASPBERRY CHIP',
     ' EGNOG '  : ' EGGNOG',
     ' CCHP ' : ' CHOCOLATE CHIP ',
      'CAFE CONLECHE'  : 'CAFÉ CON LECHE'  ,
        ' NPLTN ':' NEAPOLITAN ',
       ' STR LMND ': ' STRAWBERRY LEMONDADE ',         
        ' BNA ' : ' BANANA ' ,
         'CREAMY TRIAMISU'  : 'CREAMY TIRAMISU',
         'SCLIAN PSTCHO' : 'SICILIAN PISTACHIO',   
          'CHCGO POT HLE': 'CHICAGO POTHOLE' ,
          ' PBTR ':' PEANUT BUTTER ',   
          ' HZELNT '  : ' HAZELNUT ',
          'BAN PB CHUNK' : 'BANANA PEANUT BUTTER CHUNK', 
           'CAVEMAN CHOC' : 'CAVEMAN CHOCOLATE',
            'BULLPEN CHOC':'BULLPEN CHOCOLATE',    
              ' PB CHOC ': ' PEANUT BUTTER CHOCOLATE',
              ' BBRYPCH' : ' BLUEBERRY PEACH',
               'DB CHO SNDAE' : 'DOUBLE CHOCOLATE SUNDAE',
               ' CHO ' : ' CHOCOLATE ',
                ' NEA ': ' NEAPOLITAN ',
                ' BTRPEC ': ' BUTTER PECAN ',
                ' VANBN ': ' VANILLA BANANA ',
                ' PCH ' : ' PEACH ',
                ' RKY RD ': ' ROCKY ROAD ',
                ' BBCRMPIE ': ' BLUEBBERY CREAM PIE',
                ' SNWCRM ' : ' SNOW CREAM ',
                'CHOC/VAN' : 'CHOCOLATE VANILLA',
                'PURITYCRMLPRA': 'PURITY CARAMEL PRALINE',
                ' CML TOFF ': ' CARAMEL TOFFEE ',
                ' VN16PK': ' VANILLA 16PK',
                ' NUTCRN ': ' CHERRY NUT ',
                ' CRMLPIE ': ' CARAMEL PIE',
                 ' PPMNT ' : ' PEPPERMINT ',
                  'MSTRKPRLC' : 'MOOSE TRACKS PRALINES AND CREAM',
                  ' VCS ' : ' VANILLA CHOCOLATE STRAWBERRY ',           
  ',': ' ',
   '/': ' ',
  '>':' ',
  '<': ' '}

# %%
new_flvs_mallik = pd.read_excel(path_atb +  'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet1')
new_flvs_paul_single = pd.read_excel(path_atb + 'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet2')
new_flvs_paul_double = pd.read_excel(path_atb + 'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet3')
new_flvs_paul_multiple = pd.read_excel(path_atb + 'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet4')
new_flvs_paul_others = pd.read_excel(path_atb + 'New_Flavors_Combos_102723.xlsx', sheet_name= 'Sheet5')

# %%
newest_flavors = new_flvs_paul_single.Flavors.dropna().unique().tolist()+new_flvs_paul_double.Flavors.dropna().unique().tolist()+new_flvs_paul_multiple.Flavors.dropna().unique().tolist() + new_flvs_paul_others.Flavors.dropna().unique().tolist() + new_flvs_mallik.Flavors.str.upper().unique().tolist()

# %%
addns_descs = pd.read_csv(path_atb + 'Additional_IceCream_Descriptions_102023.csv')

# %%
### Use Other Description fields (than VND_ECOM_DSC)
masterlist = pd.read_csv(path_atb + 'ice_cream_items_org.csv', sep = '|', encoding= 'ISO-8859-1')
latest_labeled = pd.read_excel(path_atb + 'ICECREAM_OTHER_FLAVORS_101623.xlsx')
latest_labeled = latest_labeled[latest_labeled.Flavor_New.notnull()]
latest_flav_map = dict(zip(latest_labeled.GTIN_NO, latest_labeled.Flavor_New))
masterlist = masterlist[~masterlist.GTIN_NO.isin(latest_labeled.GTIN_NO.unique())]
ic_df['New_Flavor'] = ic_df.GTIN_NO.apply(lambda x: latest_flav_map[x] if x in latest_flav_map.keys() else "OTHER")
ic_df = ic_df.merge(masterlist, on = 'GTIN_NO', how = 'left')

# %%
def f_cr_vnd_map_dir(df):
    vnd_map = sorted(list(set(df.VND_BRN_NAM.str.upper())))
    del vnd_map[0]
    vnd_map
    
    vnd_map_1 = [re.sub("'", '@', x) for x in vnd_map] # replace "'" with '@'
    vnd_map_1[0:20]
    
    strx = ": @@,"
    vnd_map_replace = [ "'" + x + "'" + strx for x in vnd_map_1]
    print(f'1. vnd_map_replace[0:20] = {vnd_map_replace[0:20]} /n  vnd_map_replace[-1] = {vnd_map_replace[-1] }')
    
    vnd_map_replace= ' '.join(vnd_map_replace) # convert a list to a string
    vnd_map_replace =vnd_map_replace.rstrip(',') # drop the last comma 
    print(f'2. vnd_map_replace[0:20] = {vnd_map_replace[0:20]} /n  vnd_map_replace[-1] = {vnd_map_replace[-1] }')
    
    vnd_map_replace = re.sub("'", '"', vnd_map_replace) 
    vnd_map_replace = re.sub('@', "'", vnd_map_replace) 
    vnd_map_replace = '{' + vnd_map_replace + '}'
    print(f'vnd_map_replace[0:20] = {vnd_map_replace[0:20] }/n  vnd_map_replace[-1] = {vnd_map_replace[-1] }')
    d_vnd_replace = eval(vnd_map_replace)
    rep = {"JOY® ":'',  "KROGER® ICE PIX ": '', 'KROGER® ' :'', '+DELX* ' :'', '+PRIS* ': '' }
    d_vnd_replace = {**rep, **d_vnd_replace}
    #print(f'3. d_vnd_replace[0:20] = {d_vnd_replace[0:20]}') 
    return d_vnd_replace

# %%
## Added by Yue for removing VND BRD NAM
df_vnd_brn_name = f_read(path, 'GTIN_NO and VND_BRN_NAM_102523.csv')
df_vnd_brn_name['GTIN_NO'] = df_vnd_brn_name['GTIN_NO'].astype(np.int64)
df_vnd_brn_name['VND_BRN_NAM'] =df_vnd_brn_name.VND_BRN_NAM.fillna('')
# Out:
# file GTIN_NO and VND_BRN_NAM_102523.csv shape (5219536, 2)
#  columns: Index(['GTIN_NO', 'VND_BRN_NAM'], dtype='object')
# dtypes:
#  GTIN_NO        object
# VND_BRN_NAM    object
# dtype: object
# head:
#            GTIN_NO VND_BRN_NAM
# 0  00000000000000    Optifast
# 1  00000000000017   KENNICOTT
# 2  00000000000024         NaN
# 3  00000000000031         NaN
# 4  00000000000130         NaN

# %%
ic_df_bkup = ic_df.copy()
ic_df['GTIN_NO'] = ic_df['GTIN_NO'].astype(np.int64)
ic_df = ic_df.merge(df_vnd_brn_name, on = 'GTIN_NO', how = 'left')
d_vnd_replace = f_cr_vnd_map_dir(ic_df)
#replacements = {**d_vnd_replace , **replacements }
# Out:
# 1. vnd_map_replace[0:20] = ["'ABSOLUTE FRUIT SORBET': @@,", "'ACME ICE CREAM': @@,", "'AGAVE DREAM': @@,", "'AGGIE': @@,", "'AGLAMESIS BROTHERS': @@,", "'AIR HEADS': @@,", "'ALAMODE': @@,", "'ALDEN@S': @@,", "'ALDEN@S ORGANIC': @@,", "'ALDEN@S ORGANIC ICE CREAM': @@,", "'AMYS KITCHEN': @@,", "'ANDERSON DAIRY': @@,", "'ANGELO GELATO ITALIANO': @@,", "'ANNIE’S': @@,", "'ARCTIC ZERO': @@,", "'ATA RETAIL': @@,", "'BAKERY FRESH GOODNESS': @@,", "'BASKIN-ROBBINS': @@,", "'BECKON': @@,", "'BEN & JERRY@S': @@,"] /n  vnd_map_replace[-1] = 'YASSO FROZEN GREEK YOGURT, MINT POPPABLE - 6CT': @@,
# 2. vnd_map_replace[0:20] = 'ABSOLUTE FRUIT SORB /n  vnd_map_replace[-1] = @
# vnd_map_replace[0:20] = {"ABSOLUTE FRUIT SOR/n  vnd_map_replace[-1] = }

# %%
#### BASE FLAVOR CATEGORIES
## Core Flavors
core_flavors = ['VANILLA','CHOCOLATE','FRUIT','COOKIES AND CREAM','CHOCOLATE CHIP','CARAMEL','TOFFEE','MINT CHOCOLATE CHIP','PEANUT BUTTER','COOKIE DOUGH',\
'BUTTER PECAN','COFFEE','STRAWBERRY','MOOSE TRACKS','ROCKY ROAD','COTTON CANDY','BIRTHDAY CAKE','PUMPKIN','RED VELVET','NEAPOLITAN']
# PRIVATE SELECTION
pvt_slc_flavors = [i.replace('PREMIUM','').replace('SORBET','').replace('SHERBET','').replace('NAUTRALLY','NATURALLY') for i in pvt_slc.Flavor.unique()]
pvt_slc_flavors = [ i for i in pvt_slc_flavors if not i == 'PRIVATE SELECTION']
pvt_slc_flavors = [ i.split('NATURALLY')[0] for i in pvt_slc_flavors]
pvt_slc_flavors = [i.strip(' ') for i in pvt_slc_flavors]

#Fruits
original_fruits = ['CHERRY', 'LEMON', 'ORANGE', 'LIME', 'PEACH', 'BANANA', 'PINEAPPLE', 'BERRY', 'APPLE', 'MANGO', 'RASPBERRY', 'PASSION FRUIT', 'POMEGRANATE', 'BLUEBERRY','TANGERINE']
Fruits =  original_fruits + \
['MARIONBERRY','HUCKLEBERRY','BLACKBERRY','BILBERRY','BOYSENBERRY','WILDBERRY','CLOUDBERRY','LUCUMA','CHERIMOYA','DURIAN','RED BEAN','UBE','GRAPE','GRAPEFRUIT', 'LYCHEE',\
 'RAISIN','APRICOT','PLUM','YUZU','DRAGON FRUIT','HIBISCUS', 'PUMPKIN','COCONUT','CARROT','SWEET POTATO','TARO','WATERMELON','MELON','CANTALOUPE','HONEYDEW','FIGS','JALAPENO','PERSIMMON','GUAVA','BLACK CHERRY','BLACK RASPBERRY','ACAI','GUARANA','QUINCE','GOLDENBERRY']
#Nuts /Seeds
Nuts = ['PEANUT','ALMOND','PISTACHIO','WALNUT','BLACK WALNUT','MACADAMIA','CASHEW', 'HAZELNUT','BLACK SESAME','PECAN','NUTS','FLAX','OATMEAL','COCONUT MILK','OAT MILK','AVOCADO','TAHINI']
#Candies / Confections
Candy = ['CHOCOLATE','PEPPERMINT','FUDGE','TAFFY','BUBBLEGUM','BUBBLE GUM','MARSHMALLOW','BUTTERSCOTCH','WHITE CHOCOLATE','DARK COCOLATE', 'TRUFFLE', 'TIRAMISU', 'NAPOLEON','MACARON','GUMMY BEARS', 'TOOTSIE ROLL','GIANDUJA','NUTELLA','CAJETA','DULCE DE LECHE', 'BACIO','LICORICE','BUCKEYE','SOUR PATCH KIDS','TURTLE','HIGH FIVE CANDY BAR','SNICKERS','TWIX','BUTTERFINGER', 'BABY RUTH','HEATH','SKITTLES']
#Desserts / Baked goods
Desserts = ['TOFFEE','CINNAMON ROLL','CINNAMON BUN','MUD PIE','KING CAKE','BROWNIE','COOKIE','CANNOLI','DONUT','DOUGHNUT','WAFER','WAFFLE','WAFFLE CONE','SWIRL','FRENCH TOAST','PANCAKE','PIE','COBBLER','CHEESECAKE','SNICKERDOODLE', "S'MORES",'SMORES','SMORES', 'GRAHAM','GINGERBREAD',\
            'PRALINE','BRITTLE','CRISP','CRUMBLE','CLUSTERS','SHORTBREAD', 'TORTE', 'BLACK FOREST','TRES LECHES','FLAN','BAKLAVA','BOSTON CREAM PIE','PUDDING','ECLAIR',\
            'CREAM PUFF','CROISSANT','BREAD PUDDING','MOON PIE','GOOEY BUTTER CAKE','BRIOCHE','BISCOTTI','CREAM PIE','CUP CAKE', 'PB & J','FLUFFERNUTTER']
#Dairy products
Dairy = ['MILK','BUTTER','BROWN BUTTER','SOUR CREAM','CHEESE','CREAM CHEESE','RICOTTA','MASCARPONE','CREME FRAICHE','GOAT CHEESE']
#Sweeteners
Sweeteners = ['HONEY','BROWN SUGAR','MOLASSES','MAPLE','DATES','PALM SUGAR','SYRUP','SAUCE']
#Spices
Spices = ['GINGER','CARDAMOM','CINNAMON','NUTMEG','TURMERIC','ANISE','ALLSPICE','SPICE']
#Alcohol
Boozes = ['RUM','BRANDY','BOURBON','VODKA','TEQUILA','MEZCAL','IRISH CREAM','KAHLUA','WHISKEY','BEER','COGNAC','WINE','CHAMPAGNE','PROSECCO','MERLOT','MARGARITA','LIQUOR','LIQUEUR','AMARETTO','COINTREAU','AMARULA','PINA COLADA']
#Herbs
Herbs = ['BASIL','MINT','LAVENDER']
#Aromas
Aromas = ['ROSE','ELDERFLOWER','PANDAN','SAFFRON']
#Cereals
Cereals = ['FROSTED','FRUIT LOOPS','CHEERIOS','TOASTED RICE','RICE KRISPIES','MALT','BARLEY','COCOA PEBBLES']
##Beverages
Bevs = ['COFFEE','GREEN TEA','CHAI','ESPRESSO','CAPPUCCINO', 'MOCHA','COCOA','EGGNOG','EGG NOG','COLA','SPRITE','PEPSI','FANTA','SODA','POP','LEMONADE','LATTE', 'DR PEPPER','COKE','ROOT BEER','GRASSHOPPER','TEA','BIRTHDAY PARTY','BAIRTHDAY BASH']
Others = ['SWEAT CREAM','UNICORN','MUDSLIDE','SPUMONI','STRACCIATELLA','RAINBOW','BACON', 'RED, WHITE AND BLUE','SUPERMAN','BLUE MOON','SPRINKLE','TIN ROOF SUNDAE','STRAWBERRIES AND CREAM','PEACHES AND CREAM','BLUE RASPBERRY']
Ethnic = ['ITALIAN','FRENCH VANILLA','FRENCH SILK','ENGLISH TOFFEE','DUTCH CHOCOLATE','DANISH','SCOTCH','IRISH','GERMAN CHOCOLATE','INDIAN','JAPANESE','MEXICAN HOT CHOCOLATE','AMERICAN DREAM','KOREAN','THAI ICED TEA','THAI TEA','THAI ICED COFFEE', 'VIETNAMESE ICED COFFEE']
Process = ['TOASTED','BAKED','ROASTED','FROSTED','SHAVED','CRUSHED','SLICED','WHIPPED','DIPPED','COATED']
New = ['2IN1 SNICKERS M&Ms',
 "A LI'L BIT CHIPPY",
 'ALMOND',
 'AMARENATA',
 'AMARETTO',
 'AMERICONE DREAM',
 'ARCTIC BLAST',      
 'TRIOPOLITAN AMERICAN DREAM',     
 'AVOCADO',
  'BACETTO',
 'BACIO',
 'BADGER TRACKS',
 'BAKED',
 'BANANA',
 'BANANA CREAM PIE',
  'BANANA PEANUT BUTTER CHUNK',     
 'BANANA PUDDING',
 'BANANA SPLIT',
 'BASIL',
 'BEAR',
 'BEAR ATTACK',
 'BEAR CLAW',
 'BEAR HUG',
 'BEEHIVE FANTASY',
 'BEER',
 'BERRIES AND CREAM',
 'BERRY',
 'BEST OF BOTH',
 'BIG CHIP COOKIE',
 'BIG CHIPPER',
 'BIG DIPPER',
 'BIRTHDAY BASH',
 'BIRTHDAY CAKE',
 'BIRTHDAY PARTY',
 'BLACK CHERRY',
 'BLACK CHERRY CHOCOLATE CHIP',
 'BLACK FOREST',
 'BLACK RASPBERRY',
 'BLACK RASPBERRY CHIP',    
 'BLACK SESAME',
 'BLACK WALNUT',
 'BLACKBERRY',
 'BLUE BLAST',
 'BLUE MOON',
 'BLUEBERRY CREAM PIE',
 'BLUEBERRY PIE',
 'BOLD BREW AND BROWNIES',  
 'BONNAR BUZZ',
 'BOOM CHOCOLATTA',
 'BOSTON CREAM PIE',
 'BOURBON',
 'BRANDY',
 'BRITHDAY BLAST OREO',
 'BRITTLE',
 'BROOKIE',
 'BROOKIE DOUGH',
 'BROWN ALE CHIP',
 'BROWN BUTTER BOURBON TRUFFLE',
 'BROWN BUTTER BOURBON PECAN',     
 'BROWN COW',
 'BROWN SUGAR',
 'BROWNIE BATTER',
 'BROWNIE MOOSE TRACKS',
 'BROWNIES ON THE MOON',
 'BUBBLE GUM',
 'BUBBLEGUM',
 'BUCKEYE',
 'BUNCH CRUNCH',
 'BUNCHA CRUNCH',
 'BUNNY TRACKS',
 'BUTTER',
 'BUTTER PECAN',
 'BUTTERFINGER',
 'BUTTERSCOTCH',
 'BUTTERSCOTCH BLONDIE',
 'CACAO',
 'CAFE AU LAIT',
 'CAFFE MACHIATTO',
 'CAKE POP',     
 'CANBY BAR CRUNCH',
 'CANDY BAR',      
 'CANDY CANE',
 'CANDY CANE CUPS',
 'CANNOLI',
 'CAPPUCCINO',
 'CAPPUCCINO CHIP',
 'CARAMEL',
 'CARAMEL',
 'CARAMEL PIE',
 'CARAMEL POPCORN',
 'CARAMEL PRALINE',
 'CARAMEL TOFFEE',
 'CARIBBEAN',
 'CARIBOU COFFEE JAVA CHUNK',
 'CASHEW',
 'CASSATA SICILIANA',
 'CELEBRATION CAKE',
 'CHAI',
 'CHANGE THE WHIRLED',
 'CHCOLATE CHERRY COOKIES AND CREAM',
 'CHEESE',
 'CHEESECAKE',
 'CHERRY',
 'CHERRY CHOCOLATE CHIP',
 'CHERRY NUT',
 'CHICAGO BRICK',
 'CHICAGO POTHOLE',
 'CHIPS AHOY!',
 'CHOCOLATE',
 'CHOCOLATE CHIP',
 'CHOCOLATE CHIP COOKIE DOUGH',
 'CHOCOLATE CHIP COOKIE DOUGH AND VANILLA',
 'CHOCOLATE CHIP COOKIES & SALTED CARAMEL', 
 'CHOCOLATE HAZELNUT',
 'CHOCOLATE MALT SHOPPE',
 'CHOCOLATE PEANUT BUTTER FUDGE',      
 'CHOCOLATE PEANUT BUTTER MOOSE TRACKS',
 'CHOCOLATE PRETZEL TWIST',
 'CHUNKY CHUNKY HIPPO',
 'CHUNKY MONKEY',
 'CHUNKY PANDA',
 'CHURNED CELEBRATION',
 'CHURRAY FOR CHURROS',
 'CHURRO',
 'CHURROS CON LECHE',
 'CINNABON',
 'CINNAMON',
 'CINNAMON ROLL',
 'CINNAMON TOAST CRUNCH',
 'CINNAMONBUN',
 'CINNNAMON ROLL',
 'CLASSIC',
 'CLASSIC COUNTRY VANILLA',     
 'COATED',
 'COCONUT',
 'COCONUT MILK',
 'COCONUTMILK',
 'COFFEE',
 'COOKIE DOUGH',
 'COOKIES AND CREAM',
 'COOKIES AND CREAM CHEESECAKE CORE',   
 'COOKIES N DREAMS',
 'COSMIC BROWNIE',
 'COOKIES N CREAM',
 'COUGAR TRACKS',
 'COVFEFE',
 'CREAM CHEESE',
 'CREAM PIE',
 'CREAM PUFF',
 'CREMA SICILIANA',
 'CREME DE NOVI',
 'CRISP',
 'CRUSHED',
 'CRÈME BRULEE',
 'CUATRO LECHES',
 'CUP CAKE',
 'CUPCAKE',
 'DARK CHOCOLATE',
 'DARK SIDE OF THE MOON',
 'DARK SIDE OF THE SPOON',     
 'DEATH BY CHOCOLATE',
 'DEER TRAXX',
 'DENALI MOOSE TRACKS',     
 'DINOSAUR EGG',
 'DIPPED',
 'DIRT CAKE',
 'DIVINE INDULGENCE',
 'DONUT',
 'DOUBLE DARK',
 'DOUBLE DARK CHOCOLATE',      
 'DOUBLE DOUGH',
 'DOUBLE DUNKER',
 'DOUBLE FUDGE MOOSE',
 'DOUBLE STUFFED OREO COOKIE',
 'DOUGHNUT',    
 "DRAGON'S DREAM",
 'DREAMSICLE',
 'DUBLIN MUDSLIDE',
 'DULCE DE LECHE',
 'DUTCH',
 'EARL GREY TEA',
 'EGG NOG',
 'EGGNOG',
 'ELEPHANT EAR',
 'ELEPHANT TRACKS',
 'ESPRESSO',
 'EXTREME MAXIMUM FUDGE MOOSE TRACKS',
 'FAIRY MAGIC',
 'FANNIE MAY MINT MELTAWAYS',
 'FAVA BEAN',
 "FEELING' DANGEROUS?",
  "FEELIN' DANGEROUS?",
 'FLAN',
 'FLUFFERNUTTER',
 'FRENCH TOAST',
 'FRESAS Y CREMA',
 'FRIED',
 'FRUIT',
 'FRUITY PEBBLES',
 'FUDGE',
 'FUDGE RIPPLE',
 'FUDGE SWIRL',
 'FUDGESICLE',
 'FUNFETTI',
 'GALACTIC SWIRL'
 'GALAXY GREEN',
 "GIMME S'MORE!",
 'GIMMESMORE',
 'GIMME SOME SUGAR',      
 'GINGER',
 'GINGERBREAD',
 'GIRL SCOUTS SAMOAS',
 'GIRL SCOUTS THIN MINT',
 'GOLD MEDAL RIBBON',
 'GOLDEN OREO',
 'GOO GOO CLUSTER',
 'GOOEY BUTTER CAKE',
 'GRAHAM',
 'GRAPE',
 'GRAPEFRUIT',
 'GRASSHOPPER',
 'GREEN PUNCH',
 'GREEN TEA',
 'GUAVA',
 'HARLEY QUINN CHERRY CHOCOLATE DIAMOND DAZE',
 'HAWAIIAN',
 'HAWAIIAN PUNCH',
 'HAWAIIAN SUNDAE',
 'HAZED & CONFUSED',
 'HAZELNUT',
 'HAZELNUT COFFEE',
 'HAZZLENUT',
 'HEATH',
 'HEAVENLY HASH',
 'HERD OF COWS',
 'HIGH FIVE CANDY BAR',
 'HOKEY POKEY',
 'HOKIE TRACKS',
  'HOLIDAY',     
 'HONEY',
 'HONEY GRAHAM',     
 'HONEY IPA',
 'HONEYDEW',
 'HORCHATA',
 'HOSTESS SNOBALLS',   
 'HOWLY TOLEDO',
 'HUCKLEBERRY',
 'HUSKY TRACKS',
 'IMAGINE WHIRLED PEACE',
 'IRISH CREAM',
 'ITALIAN',
 'JAMOCA',
 'JAVA CHIP',
 'JOLLY RANCHER',
 'KING CAKE',
 'KIT KAT',
 'KIWI',
 'KLONDIKE KRUNCH',
 'KARAMELSUTRA',     
 'KOOKIE KAYLA',
 'LADY BUG',
 'LANDSLIDE',
 'LATE NIGHT SNACK',
 'LATTE',
 'LAVA FLOW',
 'LAVENDER',
 'LEMON',
 'LEMON PIE',
 'LEMONADE',
 'LICORICE',
 'LIGHTS CARAMEL ACTION',
 'LIMONCELLO',
 'LIMONE',
 'LLAMA',
 'LYCHEE',
 "M&M'S",
   'MMMS',    
 'MAGIC BROWNIES',     
 'MALT',
 'MALT BALLS',
 'MALTED MOO SHAKE',
 'MANGO',
 'MANGONADA',
 'MAPLE',
 'MAPLE FUDGE ',
 'MAPLE NUT',
 'MARGARITA',
 'MARSHMALLOW',
 'MATCHA GREEN TEA',
 'MATCHA MINT CHIP',
 'MELON',
 'MERMAID',     
 'MERMAID SPARKLE',
 'MIDNIGHT TRAIN TO TRAVERSE',
 'MILK',
 'MILKY WAY',     
 'MINIMOON',
 'MINT',
 'MINTALICIOUS',     
 'MINT BROWN COW',
 'MINT CHOCOLATE CHIP',
 'MINTCHOCCOOKIE',
 'MINTER WONDERLAND',
 'MISSISSIPPI DEBRIS',
 'MOCHA',
 'MOCHA FUDGE',
 "MOM'S MAKIN' COOKIES",
 'MONSTER MASH',
 "MOO-IONAIRE'S JAVA",
 'MOONLIGHT',
 'MOOSE DREAM',
 'MOOSE TRACKS',
 'MOOSETRACKS',
 'MOTHER LOAD',
 'MOUNTAIN BLACKBERRY',
 'MOUSSE PIE',
 'MOVIE NIGHT',
 'MRS FIELDS',
 'MUD PIE',
 'MUDPIE',
 'MUDSLIDE',
 'MUKILTEO MUDD',
 'MYSTERY MIDDLES',
 'NEAPOLITAN',
 'NESTLE 100 GRAND',
 'NESTLE DRUMSTICK SUNDAE CONE',
 "NETFLIX+CHILLED",
 "NETFLIX & CHILL'D",  
 'NETFLIX',     
 'NUT SUNDAE',
 'NUTS',
 'NUTTY BAR',
 'NUTTY BUDDY',
 'OAT OF THIS SWIRLED',
 'OATMEAL',
 'OATMEAL DREAM PIE',
 'OOEY GOOEY',
 'ORANGE',
 'OREO',
 'ORIGINAL',
 'OVERLOAD FRIED',
 'PAINTBALL BLAST',
 'PANCAKE',
 'PANCAKES AND WAFFLES',
 'PASSIONILLA',
 'PB & J',
 'P.B. DOUGH MOO-PHORIA!',  
 "PB 'N FUDGE",
 'PEACH',
 'PEACH LAMBIC',
 'PEACHES AND CREAM',
 'PEANUT',
 'PEANUT BUTTER',
 'PECAN',
 'PEPERMINT',
 'PEPPERMINT',
 'PHISH FOOD',
 'PIG TRACKS',
 'PINA COLADA',
 'PINEAPPLE',
 'PINK GRAPEFRUIT',
 "PIRATE'S BOUNTY",
 'PISTACHIO',
 'PISTACHIO HONEY',
 'PISTACCHIO',      
 'PLAY DOUGH',
 'PLUM',
 'PRALINE',
 'PRALINES AND CREAM',
 'PRALINES & CREME',     
 'PSITACHIO',
 'PUMPKIN',
 'PUMPKIN',
 'PUNCH LINE',      
 'PURPLE YAM',
 'QUEEN CITY',
 'RAINBOW',
 'RUM RAISIN',
 'RASPBERRY',   
 'RASPBERRY WHITE TRUFFLE',
 'RASPBERRY DARK CHOCOLATE',      
 'RED BEAN',
 'RED PUNCH',
 'RED VELVET',
 'RED VELVET CAKE',     
 'REDBEAN',
 'REDBERRY',
 'REDS GRAND SLAM',
 'REESES',
 'RIESLING PEAR',
 'ROASTED',
 'ROCK-IT RED',
 'ROCKY ROAD',
 'ROOT BEER',
 'ROSE',
 "S'MORE",
 "S'MORES",
 'SALTED CARAMEL',
 'SALTED CARMEL',      
 "SANTA'S COOKIES",
 'SASQUATCH TRACKS',
 'SCOTCHAROO',
 'SEASONAL FLAVOR',
 'SICILIAN PISTACHIO',
 'SKITTLES',
 'SMOKY MOUNTAIN FUDGE',
 'SMORES',
 'SNACKS ON A PLANE',
 'SNICKERDOODLE',
 'SNICKERS',
 'SNOW CONE',
 'SNOW CREAM',
 'SODA',
 'SOUR PATCH KIDS',
 'SPECULOOS',
 'SPONGEBOB SQUAREPANTS',
 'SPUMONI',
 'STRACCIATELLA',
 'STRAWBERRY',
 'STRAWBERRIES & CREAM',  
  'STRAWNANA SPLIT',   
 'SUMMER BERRY SWIRL',
 'SUNRISE BLEND',
 'SUPER MADNESS',
 'SUPER MOO',
 'SUPER SCOOP',
 'SUPER DUPER SCOOP',
 'SUPERMAN',
 'SUPERMOON',
 'SWEAT CREAM',
 'SWEET CREAM',
 "SWEET OL' JOE",
 'SWEET RELATION-CHIP',
 'SWEET SOUTHERN SOMETHING',
 'SWIRL',
 'SWISS ROLL',
 'TANGERINE',
 'TAHITIAN VANILLA BEAN WITH SHOESTRING FRENCH FRIES & MILK CHOCOLATE MALT BALLS',
 'TARO',
 'THAT"S MY JAM',
 'THE GOBFATHER',
 'THE JOKER MINT COOKIE MADNESS',
 'THE MOTHER LODE',
 'TIE DYE BURST',
 'TIGER TRACKS',
 'TIGER TRAXX',
 'TIGERNUT COOKIES AND CREAM',
 'TIN ROOF',
 'TIRAMISU',
 'TOASTED',
 'TOASTED MARSHMALLOW',    
 'TONIGHT DOUGH',
 'TONS OF TURTLES',
 'TOOTSIE ROLL',
 'TOPPED STRAWBERRY TART SWEET CREAM WITH PICE CRUST AND WHITE CHOCOLATE',
 'TRES LECHES',
 'TRIPLE CHOCOLATE',
 'TRIPLE VANILLA',
 'TROPICAL',
 'TROPICAL CITRUS',
 'TROPICAL FREEZIE',
 'TROPICAL TRUTH',
 'TRUFFLE',
 'TURMERIC',
 'TURTLE',
 'TURTLE TRACKS',
 'TWIX',
 'UNDER THE STARS',
 'UNICORN SWIRL',
 'VANILLA',
 'VANILLA CHOCOLATE CHIP',  
 'CORNFLAKE CHOCOLATE CHIP MARSHMALLOW',     
 "VANILLA 'N COOKIES",
 'VANILLA ORANGE SWIRL',      
 'VANILLA BOCK',
  'WAKE N BAKE',    
 'WAKE & "NO BAKE"',
 'WALNUT',
 'WATERMELON',
 'WHAT A CLUSTER',
 'WHISKEY',
 'WHISKEY CAKE',
 'WHISKY',
 'WHITE CHOCOLATE',
 'WHITEHOUSE',
 'WHOOPIE PIES AND SWEET CREAM',
 "WILD 'N RECKLESS",
 'WILDBERRY',
  'WILD BERRIES' ,    
 'WILDBERRY MARSCAPONE LAVENDER',
 'WITCH',
 'WONDER WOMAN GOLDEN LASSO TWIRL',
 'YETI',
 'YUZU',
 'ZEBRA CAKE',
 'ZEBRA STRIPES',
 'DOVE BAR MINIS VANILLA CHOCOLATE CHIP WITH MILK CHOCOLATE BARS',
 'CORNFLAKE CHOCOLATE CHIP MARSHMALLOW',
 'CANDY CANE CHOCOLATE CHIP CORNFLAKE',
 'CHOCOLATE CHIP COOKIE DOUGH',
 'CHOCOLATE CHIP COOKIES & VANILLA & DIPPED MILK CHOCOLATE']
Flavors_combo = list(set(core_flavors + pvt_slc_flavors + Fruits + Nuts + Candy + Desserts + Dairy + Sweeteners + Spices + Boozes + Herbs + Cereals + Aromas + Bevs +Others + Ethnic + Process + New + newest_flavors))
#Flavors_combo = pd.Series(Flavors_combo).replace(d_vnd_replace).replace(replacements, regex= True).to_list()
Flavors_combo = pd.Series(Flavors_combo).replace(replacements, regex= True).to_list()
drop_flavors = ['EVERYTHING BUT THE…']
Flavors_combo = [ i for i in Flavors_combo if not i in drop_flavors]
Flavors_combo_bnj = Flavors_combo + bnj_flvs_ct

# %%
### Remove substrings like 'CHOCOLATE' if 'CHOCOLATE CHIP' is also present as a top result
def remove_substrings(string_list):
    str_df = pd.DataFrame(string_list, columns= ['Sentence'])
    str_df['Word Length'] = str_df.Sentence.apply(lambda x: len(x.split(' ')))
    str_df['Drop'] = ''
    str_df.sort_values('Word Length', inplace= True)
    str_df.reset_index(drop = True, inplace= True)
    for j in range(len(str_df)):
        str_1 = str_df.Sentence.loc[j]
        for i in range(len(str_df)-(j +1)):
            str_2 = str_df.Sentence.loc[i+j+1]
            if str_1 in str_2: 
                str_df.Drop.loc[j] = 'Yes'
                break
        if len(str_df) <2: 
            break
    return str_df[str_df.Drop != 'Yes'].Sentence.tolist()

# %%
def devowelize(string):
    return ''.join([i for ix,i in enumerate(string) if  ix ==0 or i not in 'AEIOUaeiou'])
def remove_adjacent_repititions(string):
    string = devowelize(string)
    pos_map = dict(zip(range(len(string)),[i for i in string]))
    return ''.join([val for (key,val) in pos_map.items() if (key == (len(string) -1)) or (pos_map[key +1] != val) ])

# %%
#MAtch using 'token set ratio' with threshold
def flavor_match(item, flavor_list_org, cutoff = 85):
    #devowelized = [devowelize(i) for i in flavor_list_org]
    #derepeated = [remove_adjacent_repititions(i) for i in flavor_list_org]
    flavor_list = [i.strip(' ') for i in flavor_list_org] #+ devowelized
    #flavor_list += derepeated
    #abbrev_maps = dict(zip(devowelized+ derepeated, flavor_list_org + flavor_list_org))
    #flavors_no_spaces = [i for i in flavor_list_org if not ' ' in i]
    #flavors_with_spaces = [i for i in Flavors_combo_bnj if ' ' in i]
    
    abbrev_maps = {}
    '''for i in flavors_no_spaces:
        for j in flavors_with_spaces:
            if j.replace(' ','') == i:
                abbrev_maps[i] = j'''
    abbrev_maps['NETFLIX']  = 'NETFLIX & CHILLED'   
    abbrev_maps['WAKE N BAKE'] = 'WAKE & NO BAKE'
    abbrev_maps['GIMMESMORE'] = "GIMME S'MORE!"
    abbrev_maps["GIMME S'MORE"] = "GIMME S'MORE!"
    abbrev_maps["COOKIES & CREAM"] = "COOKIES AND CREAM"
    abbrev_maps['MILK&COOKIES'] = 'MILK & COOKIES'
    if item in flavor_list: 
        matched = item
        if item in abbrev_maps.keys():
            matched = abbrev_maps[item]
        flavor_count = 1
        fuzz_score = 100
    else:    
        matched = process.extract(item, flavor_list, score_cutoff= cutoff, scorer = fuzz.token_set_ratio, processor=utils.default_process, limit = 50)
        flavor_shortlist = [i[0] for i in matched]
        matched = [i for i in matched if i[0] in flavor_shortlist]
        if len( flavor_shortlist) >0:
            max_score = matched[0][1]
            final_match = [ i for i in matched if i[1]>= cutoff]
            match_list = [i[0] for i in final_match]
            match_list = [abbrev_maps[i] if i in abbrev_maps.keys() else i for i in match_list]
            # Second match using fuzz.partial_ratio
            rematched = process.extract(item, match_list, scorer = fuzz.partial_ratio, processor=utils.default_process, limit = 5)
            re_max_score = rematched[0][1]
            final_rematch = [ i for i in rematched if i[1]== re_max_score]
            match_list =  [i[0] for i in final_rematch]
            match_list = remove_substrings(match_list)
            match_list_ordered =[]
            for word in item.split(' '):#Ordering matching flavors according to thair appearance in the description text
                for flavor_token in match_list:
                    if word in flavor_token:
                        match_list_ordered.append(flavor_token)
                        continue
            if len(match_list_ordered) >0:
                match_list = pd.Series(match_list_ordered).drop_duplicates().tolist()
            else:
                match_list = pd.Series(match_list).drop_duplicates().tolist()
            
            '''
            match_list = [flavor_maps[i] if i in flavor_maps.keys() else i for i in match_list]
            if set(match_list) == {'STRAWBERRY','FRUIT'}: 
                match_list = ['FRUIT']#Drop Strawberry if fruit is the only other flavor
            if  set(match_list) != {'FRUIT'} : match_list = [ i for i in match_list if i != 'FRUIT']#Drop Fruit if it appears with something else

            if matched in multiflavor_dict.keys(): #Mapping multi-flavors to intended labels
                matched = multiflavor_dict[matched]
            '''
            flavor_count = len(set(match_list))
            matched = '|'.join(list(pd.Series(match_list)))
            fuzz_score = max_score

        else: 
            matched = 'OTHER'
            flavor_count = 0
            fuzz_score = 0
    return (matched, flavor_count, fuzz_score)

# %%
# Include de-vowelized versions of descriptions to reattempt try to match 'OTHERS'
def flavor_match_other(item, flavor_list_org, cutoff = 95):
    devowelized = [devowelize(i) for i in flavor_list_org]
    derepeated = [remove_adjacent_repititions(i) for i in flavor_list_org]
    flavor_list = [i.strip(' ') for i in flavor_list_org] + devowelized
    flavor_list += derepeated
    abbrev_maps = dict(zip(devowelized+ derepeated, flavor_list_org + flavor_list_org))
    #flavors_no_spaces = [i for i in flavor_list_org if not ' ' in i]
    #flavors_with_spaces = [i for i in Flavors_combo_bnj if ' ' in i]
    
    #abbrev_maps = {}
    '''for i in flavors_no_spaces:
        for j in flavors_with_spaces:
            if j.replace(' ','') == i:
                abbrev_maps[i] = j'''
    abbrev_maps['NETFLIX']  = 'NETFLIX & CHILLED'   
    abbrev_maps['WAKE N BAKE'] = 'WAKE & NO BAKE'
    abbrev_maps['GIMMESMORE'] = "GIMME S'MORE!"
    abbrev_maps["GIMME S'MORE"] = "GIMME S'MORE!"
    abbrev_maps["COOKIES & CREAM"] = "COOKIES AND CREAM"
    abbrev_maps['MILK&COOKIES'] = 'MILK & COOKIES'
   
        
    matched = process.extract(item, flavor_list, score_cutoff= cutoff, scorer = fuzz.partial_ratio, processor=utils.default_process, limit = 10)
    flavor_shortlist = [i[0] for i in matched]
    matched = [i for i in matched if i[0] in flavor_shortlist]
    if len( flavor_shortlist) >0:
        max_score = matched[0][1]
        final_match = [ i for i in matched if i[1]>= cutoff]
        match_list = [i[0] for i in final_match]
        match_list = [abbrev_maps[i] if i in abbrev_maps.keys() else i for i in match_list]
        # Second match using fuzz.partial_ratio
        '''rematched = process.extract(item, match_list, scorer = fuzz.partial_ratio, processor=utils.default_process, limit = 5)
        re_max_score = rematched[0][1]
        final_rematch = [ i for i in rematched if i[1]== re_max_score]
        match_list =  [i[0] for i in final_rematch]
        match_list = remove_substrings(match_list)'''
        match_list_ordered =[]
        for word in item.split(' '):#Ordering matching flavors according to thair appearance in the description text
            for flavor_token in match_list:
                if word in flavor_token:
                    match_list_ordered.append(flavor_token)
                    continue
        if len(match_list_ordered) >0:
            match_list = pd.Series(match_list_ordered).drop_duplicates().tolist()
        else:
            match_list = pd.Series(match_list).drop_duplicates().tolist()
        '''
        match_list = [flavor_maps[i] if i in flavor_maps.keys() else i for i in match_list]
        if set(match_list) == {'STRAWBERRY','FRUIT'}: 
            match_list = ['FRUIT']#Drop Strawberry if fruit is the only other flavor
        if  set(match_list) != {'FRUIT'} : match_list = [ i for i in match_list if i != 'FRUIT']#Drop Fruit if it appears with something else

        if matched in multiflavor_dict.keys(): #Mapping multi-flavors to intended labels
            matched = multiflavor_dict[matched]
        '''
        flavor_count = len(set(match_list))
        matched = '|'.join(list(pd.Series(match_list)))
        fuzz_score = max_score

    else: 
        matched = 'OTHER'
        flavor_count = 0
        fuzz_score = 0
    return (matched, flavor_count, fuzz_score)

# %%
### Paul's corrected items 
corrected_single = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= 'Single_Flavors')
corrected_double = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= '2_Flavors')
corrected_multiple = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= '3_plus__Flavors')
corrected_others = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102523__Pauls_Corrections.xlsx', sheet_name= 'OTHERs')
corr_cols = ['GTIN_NO','CORRECTED']
corrected = pd.concat\
([corrected_single[corr_cols],corrected_double[corr_cols],corrected_multiple[corr_cols],corrected_others[corr_cols]])
corrected = corrected[corrected.CORRECTED.notnull()]

# %%
ic_df_corrected = ic_df[ic_df.GTIN_NO.isin(corrected.GTIN_NO.unique())]
ic_df = ic_df[~ic_df.GTIN_NO.isin(corrected.GTIN_NO.unique())]
ic_df_corrected['Detected_Flavor(s)']=  ic_df_corrected.GTIN_NO.\
apply(lambda x: (dict(zip(corrected.GTIN_NO,corrected.CORRECTED))[x],1, 100) )

# %%
# Fuzzy Matching Ben & Jerry's items on Flavor List
ic_df_bnj = ic_df[ic_df.VND_ECOM_DSC.str.contains('Ben & Jerry')]
ic_df = ic_df[~ic_df.VND_ECOM_DSC.str.contains('Ben & Jerry')]
ic_df_bnj['Detected_Flavor(s)']= \
ic_df_bnj.ECOMMERCE_DESCRIPTION.fillna('').str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo_bnj + [i.replace(" ","") for  i in  Flavors_combo_bnj] ))

# %%
ic_df_bnj_vnd_ecom = ic_df_bnj[ic_df_bnj['Detected_Flavor(s)']==('OTHER',0,0)]
ic_df_bnj = ic_df_bnj[ic_df_bnj['Detected_Flavor(s)']!=('OTHER',0,0)]
ic_df_bnj_vnd_ecom['Detected_Flavor(s)']= \
ic_df_bnj_vnd_ecom.VND_ECOM_DSC.fillna('').str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo_bnj + [i.replace(" ","") for  i in  Flavors_combo_bnj] ))
ic_df_bnj_vnd_ecom_other = ic_df_bnj_vnd_ecom[ic_df_bnj_vnd_ecom['Detected_Flavor(s)']==('OTHER',0,0)]
ic_df_bnj_vnd_ecom = ic_df_bnj_vnd_ecom[ic_df_bnj_vnd_ecom['Detected_Flavor(s)']!=('OTHER',0,0)]
ic_df_bnj = pd.concat([ic_df_bnj, ic_df_bnj_vnd_ecom])
ic_df = pd.concat([ic_df_bnj_vnd_ecom_other,ic_df])

# %%
# Fuzzy Matching ECOMMERCE_DESCRIPTION on Flavor List
ic_df['Detected_Flavor(s)']= \
ic_df.ECOMMERCE_DESCRIPTION.fillna('').str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))

# %%
ic_df.rename(columns= {'Flavor':'Original_Flavor'}, inplace= True)

# %%
#separate out 'OTHERS'
ic_df_ECOM_flv = ic_df[ic_df['Detected_Flavor(s)'] != ('OTHER',0,0)]
ic_df = ic_df[ic_df['Detected_Flavor(s)'] == ('OTHER',0,0)]

# %%
# VND _ECOM_DSC Fuzzy Matching on Flavor List
ic_df['Detected_Flavor(s)']= \
ic_df.VND_ECOM_DSC.str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))

# %%
#separate out 'OTHERS'
ic_df_VND_ECOM_flv = ic_df[ic_df['Detected_Flavor(s)'] != ('OTHER',0,0)]
ic_df = ic_df[ic_df['Detected_Flavor(s)'] == ('OTHER',0,0)]

# %%
# TAG_DESCRIPTION Fuzzy Matching on Flavor List
ic_df['Detected_Flavor(s)']= \
ic_df.TAG_DESCRIPTION.str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))

# %%
#separate out 'OTHERS'
ic_df_TAG_DSC_flv = ic_df[ic_df['Detected_Flavor(s)'] != ('OTHER',0,0)]
ic_df = ic_df[ic_df['Detected_Flavor(s)'] == ('OTHER',0,0)]

# %%
# PRODUCT_DESCRIPTION Fuzzy Matching on Flavor List
#from pandas.core.common import SettingWithCopyWarning
ic_df['Detected_Flavor(s)']= \
ic_df['PRODUCT_DESCRIPTION/MKT_MSG'].str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))

# %% [markdown]
# ic_df_others = ic_df[ic_df['Detected_Flavor(s)'] == ('OTHER',0,0)]
# ic_df = ic_df[ic_df['Detected_Flavor(s)'] != ('OTHER',0,0)]

# %% [markdown]
# #Retrying OTHERs using de-vowelized string match
# ic_df_others['Detected_Flavor(s)']= \
# ic_df_others.VND_ECOM_DSC.str.upper().replace(replacements, regex = True).apply(lambda x:flavor_match_other(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))

# %%
'''
ic_df_others_ECOM = ic_df_others[ic_df_others['Detected_Flavor(s)'] == ('OTHER',0,0)]
ic_df_others = ic_df_others[ic_df_others['Detected_Flavor(s)'] != ('OTHER',0,0)]
ic_df_others_ECOM['Detected_Flavor(s)']= \
ic_df_others_ECOM.ECOMMERCE_DESCRIPTION.str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match_other(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))
'''
# Out:
# '\nic_df_others_ECOM = ic_df_others[ic_df_others[\'Detected_Flavor(s)\'] == (\'OTHER\',0,0)]\nic_df_others = ic_df_others[ic_df_others[\'Detected_Flavor(s)\'] != (\'OTHER\',0,0)]\nic_df_others_ECOM[\'Detected_Flavor(s)\']= ic_df_others_ECOM.ECOMMERCE_DESCRIPTION.str.upper().replace(d_vnd_replace).replace(replacements, regex = True).apply(lambda x:flavor_match_other(x, flavor_list_org= Flavors_combo + [i.replace(" ","") for  i in  Flavors_combo] ))\n'

# %%
flavors_all = pd.concat([ic_df_corrected,ic_df_bnj, ic_df_ECOM_flv, ic_df_VND_ECOM_flv, ic_df_TAG_DSC_flv,ic_df])#_others,ic_df])
flavors_all['Flavor'] = flavors_all['Detected_Flavor(s)'].apply(lambda x: x[0])
flavors_all['Flavor_Count'] = flavors_all['Detected_Flavor(s)'].apply(lambda x: x[1])
flavors_all['Match_Score'] = flavors_all['Detected_Flavor(s)'].apply(lambda x: x[2])

# %%
flavors_all['Flavor_Reps'] = flavors_all.Flavor.apply(lambda x: pd.Series(x.split(' ')).value_counts()[0] >1)
flavors_all['Flavor_Word_Count'] = flavors_all.Flavor.apply(lambda x: len(x.split(' ')))

# %%
flavors_all = flavors_all[flavors_all.PID_COM_DSC != 'SPICES & EXTRACTS']# Remove Non-ICE cream items
flavors_all.drop_duplicates('GTIN_NO', inplace = True)

# %%
#Postprocessing 
flavors_no_spaces = [i for i in flavors_all.Flavor.unique() if not ' ' in i]
flavors_with_spaces = [i for i in Flavors_combo_bnj if ' ' in i]
add_spaces_map = {}
for fl in flavors_with_spaces:
    fl_nospaces = fl.replace(' ','')
    if fl_nospaces in flavors_no_spaces:
        add_spaces_map[fl_nospaces] = fl
add_spaces_map
# Out:
# {'MOUSSEPIE': 'MOUSSE PIE',
#  'COCONUTMILK': 'COCONUT MILK',
#  'PHISHFOOD': 'PHISH FOOD',
#  'REDBEAN': 'RED BEAN',
#  'SUPERSCOOP': 'SUPER SCOOP',
#  'MALTBALLS': 'MALT BALLS',
#  'KARAMELSUTRA': 'KARAMEL SUTRA',
#  'EGGNOG': 'EGG NOG',
#  'OATMEALDREAMPIE': 'OATMEAL DREAM PIE',
#  'CHURRAYFORCHURROS': 'CHURRAY FOR CHURROS',
#  'AMERICONEDREAM': 'AMERICONE DREAM',
#  'SNOWCONE': 'SNOW CONE',
#  'MUDPIE': 'MUD PIE',
#  'CUPCAKE': 'CUP CAKE',
#  'PB&J': 'PB & J',
#  'BUBBLEGUM': 'BUBBLE GUM',
#  'LIGHTSCARAMELACTION': 'LIGHTS CARAMEL ACTION',
#  'MOOSETRACKS': 'MOOSE TRACKS'}

# %%
flavors_all['Flavor'] = \
flavors_all.Flavor.\
apply(lambda x: ' '.join([add_spaces_map[i]  if i in add_spaces_map.keys() else i for i in x.split('|')]))

# %%
bef_single  =  pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102723_v5.xlsx', sheet_name= 'Single_Flavors')
bef_single['Flavor_Count']  = 1
bef_double =   pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102723_v5.xlsx', sheet_name= '2_Flavors')
bef_double ['Flavor_Count']  = 2
bef_multiple = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102723_v5.xlsx', sheet_name= '3_plus__Flavors')
bef_multiple['Flavor_Count']  = 3
bef_others   = pd.read_excel(path_atb + 'ICE_CREAM_FLAVORS_102723_v5.xlsx', sheet_name= 'OTHERs')
bef_others['Flavor_Count']  = 0

# %%
flavor_all_bef = pd.concat([bef_single,  bef_double, bef_multiple, bef_others])

# %%
# Write output to excel
output_cols = ['GTIN_NO','ECOMMERCE_DESCRIPTION','VND_ECOM_DSC','TAG_DESCRIPTION','PRODUCT_DESCRIPTION/MKT_MSG','Flavor','Match_Score']
out_col = output_cols + ['Flavor_Count', 'Detected_Flavor(s)']
with pd.ExcelWriter(path_atb + "ICE_CREAM_FLAVORS_RMV_VND_BRN_NAM102723_v5.xlsx") as writer:
   
    # use to_excel function and specify the sheet_name and index 
    # to store the dataframe in specified sheet
    flavors_all[flavors_all.Flavor_Count ==1][output_cols].to_excel(writer, sheet_name="Single_Flavors", index=False)
    flavors_all[flavors_all.Flavor_Count ==2][output_cols].to_excel(writer, sheet_name="2_Flavors", index=False)
    flavors_all[flavors_all.Flavor_Count >2][output_cols].to_excel(writer, sheet_name="3_plus__Flavors", index=False)
    flavors_all[flavors_all.Flavor== 'OTHER'][output_cols].to_excel(writer, sheet_name="OTHERs", index=False)
    pd.merge(flavors_all[flavors_all.Flavor_Count ==1][output_cols], bef_single[['GTIN_NO', 'Flavor']],  on='GTIN_NO',    how='outer').to_excel(writer, sheet_name="com 1 flav", index=False)
    pd.merge(flavors_all[flavors_all.Flavor_Count ==2][output_cols], bef_double[['GTIN_NO', 'Flavor']],  on='GTIN_NO',    how='outer').to_excel(writer, sheet_name="cmp 2 flav", index=False)
    pd.merge(flavors_all[flavors_all.Flavor_Count > 2][output_cols], bef_multiple[['GTIN_NO', 'Flavor']],  on='GTIN_NO',  how='outer').to_excel(writer, sheet_name="cmp 3_plus flav", index=False)
    pd.merge(flavors_all[flavors_all.Flavor== 'OTHER'][output_cols], bef_others[['GTIN_NO', 'Flavor']],  on='GTIN_NO',    how='outer').to_excel(writer, sheet_name="cmp OTHERs", index=False)
    pd.merge(flavors_all[out_col], flavor_all_bef[['GTIN_NO', 'Flavor','Flavor_Count']], on='GTIN_NO', how = 'outer').to_excel(writer, sheet_name="cmp flavor all", index=False)

# %%
d_vnd_replace
# Out:
# {'JOY® ': '',
#  'KROGER® ICE PIX ': '',
#  'KROGER® ': '',
#  '+DELX* ': '',
#  '+PRIS* ': '',
#  'ABSOLUTE FRUIT SORBET': '',
#  'ACME ICE CREAM': '',
#  'AGAVE DREAM': '',
#  'AGGIE': '',
#  'AGLAMESIS BROTHERS': '',
#  'AIR HEADS': '',
#  'ALAMODE': '',
#  "ALDEN'S": '',
#  "ALDEN'S ORGANIC": '',
#  "ALDEN'S ORGANIC ICE CREAM": '',
#  'AMYS KITCHEN': '',
#  'ANDERSON DAIRY': '',
#  'ANGELO GELATO ITALIANO': '',
#  'ANNIE’S': '',
#  'ARCTIC ZERO': '',
#  'ATA RETAIL': '',
#  'BAKERY FRESH GOODNESS': '',
#  'BASKIN-ROBBINS': '',
#  'BECKON': '',
#  "BEN & JERRY'S": '',
#  'BEN & JERRYS': '',
#  "BEN\xa0&\xa0JERRY'S": '',
#  'BETTER TOGETHER': '',
#  'BEYOND BETTER FOODS': '',
#  'BFG': '',
#  'BIG CHIPPER': '',
#  'BLACK MARKET GELATO': '',
#  'BLUE BELL': '',
#  'BLUE BUNNY': '',
#  'BLUE BUNNY FROZEN': '',
#  'BLUE RIBBON': '',
#  'BLUE RIBBON CLASSICS': '',
#  'BOLIS': '',
#  'BOMB POP': '',
#  'BONBON GELATO & ICECREAM': '',
#  'BRAVE ROBOT': '',
#  'BREYERS': '',
#  'BROTHERS ICE CREAM': '',
#  "BUBBIE'S": '',
#  'BUBBIES': '',
#  'BUDGET $AVER': '',
#  'BUDGET $AVER®': '',
#  'BUDGET SAVER': '',
#  'CADO': '',
#  'CAFÉ BARS': '',
#  'CARVEL': '',
#  'CEDAR CREST': '',
#  'CEDAR CREST ICE CREAM': '',
#  'CENTRAL DAIRY': '',
#  'CHAR CRUST': '',
#  'CHILLY COW': '',
#  'CHIPS AHOY!': '',
#  "CHLOE'S": '',
#  "CHLOE'S SOFT SERVE FRUIT CO.": '',
#  'CIAO BELLA': '',
#  'CIAO BELLA GELATO COMPANY': '',
#  'CLIO': '',
#  'COCONUT BLISS': '',
#  'COLD STONE CREAMERY': '',
#  'CONCORD FOODS': '',
#  'COOL CLASSICS': '',
#  'COOL CLASSICS ICE PIX': '',
#  'COOL SPLASHERS': '',
#  'COOLHAUS': '',
#  'COSMIC BLISS': '',
#  'COUNTRY CHARM': '',
#  'COUNTRY FRESH': '',
#  'CRAFTSMAN': '',
#  'CRANK & BOOM BLKBRY & BTRMLK IC': '',
#  'CRANK & BOOM BOURBON HONEY IC': '',
#  'CRANK & BOOM COFFEE STOUT IC': '',
#  'CRANK & BOOM KY DK CHOC TRFL IC': '',
#  'CRANK & BOOM STRWBRY IC': '',
#  'CRANK & BOOM SUPER FUDGE IC': '',
#  'CRANK & BOOM VANILLA BEAN IC': '',
#  'CREAM + SUGAR': '',
#  "CREAM'WICH": '',
#  'CREAMALICIOUS INC.': '',
#  'CREAMIES': '',
#  'CRUNCH': '',
#  'CRYSTAL CREAMERY': '',
#  'CULTURE REPUBLICK': '',
#  'CYRSTAL': '',
#  "DAILY'S": '',
#  'DAIYA': '',
#  'DC SUPER HERO ICE CREAM': '',
#  "DEAN'S": '',
#  "DEAN'S COUNTRY FRESH": '',
#  'DEANS': '',
#  "DEEBEE'S ORGANICS INC.": '',
#  'DELUXE': '',
#  'DELUXE JAMMED': '',
#  'DENALI': '',
#  'DENTONS': '',
#  "DIANA'S": '',
#  "DIANA'S BANANAS": '',
#  'DIBS': '',
#  'DINOCI DAIRY FREE': '',
#  'DIVINO': '',
#  'DOUGHP': '',
#  'DOVE': '',
#  'DREAM BRANDS': '',
#  'DREAM POPS': '',
#  'DREAMLAND CREAMERY': '',
#  "DREYER'S": '',
#  "DREYER'S/EDY'S": '',
#  'DREYERS EDYS': '',
#  'DREYER’S/EDY’S': '',
#  'DRUMSTICK': '',
#  "EBERHARD'S DAIRY": '',
#  'EBERHARDS': '',
#  'ECLIPSE': '',
#  'EDWARD & SONS': '',
#  "EDY'S": '',
#  "EDY'S/DREYER'S": '',
#  'EL MEXICANO': '',
#  'ELEVATED ICE CREAM': '',
#  'ELIS': '',
#  'ENLIGHTENED': '',
#  'ENLIGHTENED ICE CREAM': '',
#  'F REAL': '',
#  "F'REAL": '',
#  'FAIRLIFE': '',
#  'FARR': '',
#  'FATBOY': '',
#  'FIGO! ORGANIC GELATO': '',
#  'FISHER': '',
#  'FLAVOR ICE': '',
#  'FLAVORICE': '',
#  'FOODMARK': '',
#  'FORMOSA YAY': '',
#  "FRAN'S": '',
#  "FRIENDLY'S": '',
#  'FRONEN': '',
#  'FROOZER': '',
#  'FROZEN PINTS': '',
#  'FRUTERO': '',
#  'FRUTTARE': '',
#  'FRÖNEN': '',
#  'FUDGSICLE': '',
#  'FVI SOUR PATCH KIDS': '',
#  'GELATO BOY': '',
#  'GELATO PETRINI': '',
#  "GELATY'S": '',
#  'GELATYS': '',
#  'GHIRARDELLI': '',
#  'GILLES': '',
#  'GLENVIEW FARMS': '',
#  'GODIVA': '',
#  'GOOD HUMOR': '',
#  'GOODPOP': '',
#  'GOOD\xa0HUMOR': '',
#  "GRAETER'S": '',
#  'GRAETERS': '',
#  'GUERNSEY FARMS DAIRY': '',
#  'GUILT FREE': '',
#  'HAAGEN': '',
#  'HAAGEN DAZS': '',
#  'HAAGEN-DAZS': '',
#  'HAITAI': '',
#  'HALO TOP': '',
#  'HALO TOP CREAMERY': '',
#  'HALO TOP ICE CREAM': '',
#  'HALO TOP ICE CREAM PINT': '',
#  'HARMONY VALLEY CREAMERY': '',
#  'HARRIS TEETER': '',
#  'HAWAIIAN PUNCH': '',
#  'HEALTHY CHOICE': '',
#  'HELADOS MEXICO': '',
#  'HEMISFARES': '',
#  'HERSHEY': '',
#  "HERSHEY'S": '',
#  'HILAND': '',
#  'HM 12CT VARIETY BAG': '',
#  'HOKULIA': '',
#  'HOMEMADE': '',
#  'HOMEMADE BRAND': '',
#  'HOMEMADE DAIRY FREE': '',
#  'HOMESTEAD CREAMERY': '',
#  'HOMESTEAD CREAMERY, INC.': '',
#  'HONEYSUCKLE': '',
#  'HOSTESS': '',
#  'HOT CAKES': '',
#  'HOT SCREAM': '',
#  'HOTSCREAM': '',
#  'HOTSCREAM CHOCOLATE': '',
#  'HOTSCREAM ESPRESSO': '',
#  'HOTSCREAM SALTED CARAMEL': '',
#  'HOTSCREAM STRAWBERRY': '',
#  'HOWLING COW': '',
#  'HT TRADERS': '',
#  'HUDSONVILLE': '',
#  'HUDSONVILLE ICE CREAM': '',
#  'I MEI': '',
#  'ICE CREAM FACTORY': '',
#  'ICEE': '',
#  'IMAGINE FROZEN': '',
#  'IMURAYA': '',
#  "IT'S-IT ICE CREAM": '',
#  'ITTIBITZ': '',
#  'JCS PIE POPS': '',
#  "JENI'S": '',
#  "JENI'S SPLENDID ICE CREAMS": '',
#  'JOLLY LLAMA': '',
#  'JOLLY RANCHER': '',
#  'JON DONAIRE': '',
#  'JONNY POPS': '',
#  'JONNYPOPS': '',
#  'JOY': '',
#  'JUICY JUICE': '',
#  "JULIE'S ORGANIC ICE CREAM": '',
#  'JULIES ORGANIC': '',
#  'KATZ': '',
#  'KEEBLER': '',
#  'KEEBLER - CONES': '',
#  'KEMPS': '',
#  'KETO': '',
#  'KETO PINT': '',
#  'KETO PINT MINT CHIP BAR': '',
#  'KETO PINT PEANUT BUTTER CUP BAR': '',
#  'KETO PINT SEA SALT CARAMEL BAR': '',
#  'KILLER CREAMERY': '',
#  'KIND': '',
#  'KIND FROZEN': '',
#  'KINGS CUPBOARD': '',
#  'KIT KAT': '',
#  "KLEIN'S ICE CREAM": '',
#  'KLEINS': '',
#  'KLEINS REAL KOSHER ICE CREAM': '',
#  'KLONDIKE': '',
#  'KLONDIKE CONES!': '',
#  'KOZLOWSKI FARMS': '',
#  'KROGER': '',
#  'KROGER ARCTIC BLASTERS': '',
#  'KROGER DELUXE': '',
#  'KROGER DELUXE JAMMED': '',
#  'KROGER ICE PIX': '',
#  'KROGER PARTY PAIL': '',
#  'KROGER VALUE': '',
#  'LA LOOS': '',
#  'LA MICHOACANA': '',
#  'LA NETA': '',
#  'LACTAID': '',
#  "LALOO'S": '',
#  'LAVALEE': '',
#  "LET'S DO...": '',
#  'LETS DO ORGANIC': '',
#  'LIFEWAY': '',
#  "LINDY'S HOMEMADE": '',
#  'LINDYS': '',
#  'LITTLE DEBBIE': '',
#  'LITTLE SOMETHING FOODS': '',
#  'LOPEZ ISLAND CREAMERY': '',
#  'LOTUS BISCOFF': '',
#  'LOUISVILLE CREAM LLC': '',
#  "LOVIN' SCOOPFUL": '',
#  "LUIGI'S": '',
#  'LUIGIS': '',
#  "LUNA AND LARRY'S COCONUT BLISS": '',
#  "M&M'S": '',
#  'MADISON BROWN': '',
#  "MADISONO'S": '',
#  "MADISONO'S BANANAS FOSTER GELATO": '',
#  "MADISONO'S BLUEBERRY GINGER SORBETTO": '',
#  "MADISONO'S CAFE MOCHA GELATO": '',
#  "MADISONO'S CARAMELLO & SEA SALT": '',
#  "MADISONO'S DARK CHOCOLATE ORANGE GELATO": '',
#  "MADISONO'S DOUBLE DARK CHOCOLATE GELATO": '',
#  "MADISONO'S HOKEY POKEY GELATO": '',
#  "MADISONO'S LEMON BASIL SORBETTO": '',
#  "MADISONO'S MADAGASCAR VANILLA GELATO": '',
#  "MADISONO'S PINK GRAPEFRUIT SORBETTO": '',
#  "MADISONO'S RED RASPBERRY SORBETTO": '',
#  "MADISONO'S STRAWBERRY LEMON SORBETTO": '',
#  "MADISONO'S TOASTE COCONUT & CARAMEL GELATO": '',
#  'MADISONOS': '',
#  'MAEDA EN': '',
#  'MAEDA-EN': '',
#  'MAGNUM': '',
#  'MAIN AVENUE CREAMERY - BUCKEYE FUDGE SWIRL': '',
#  'MARION KAY': '',
#  'MAUNA LOA': '',
#  'MAVENS CREAMERY': '',
#  'MAVERS CREAMERY': '',
#  "MAXINE'S ICE CREAM": '',
#  'MAYFIELD': '',
#  'MAYFIELD CREAMERY': '',
#  'MAYFIELD DAIRY FARMS': '',
#  "MCCONNELL'S FINE ICE CREAMS": '',
#  'MCCONNELLS': '',
#  'MEADOW GOLD': '',
#  'MELONA': '',
#  'MEYER ICE CREAM, LLC': '',
#  'MEZZETTA': '',
#  'MICKEY MOUSE': '',
#  'MIKAWAYA': '',
#  'MILK BAR': '',
#  'MILKY WAY': '',
#  'MINUTE MAID': '',
#  'MIXMI FROZEN YOGURT': '',
#  'MODERN POP': '',
#  'MODERN POP, INC.': '',
#  "MOLLY MOON'S": '',
#  "MOLLY MOON'S HOMEMADE ICE CREAM": '',
#  'MOONDANCE': '',
#  'MOTTS': '',
#  'MR GREEN TEA ICE CREAM COMPANY': '',
#  'MR MOCHI': '',
#  'MRS FIELDS DESSERT TOPPINGS - CHOCOLATE CHIP 8.5OZ / 10CT': '',
#  "MRS. RICHARDSON'S": '',
#  'MY MO': '',
#  'MY/MO': '',
#  'MY/MOCHI': '',
#  'MYMO': '',
#  "N!CK'S": '',
#  "N!CK'S ICE CREAM": '',
#  'NADA MOO!': '',
#  'NADAMOO': '',
#  "NANCY'S FANCY": '',
#  'NATURAL DECADENCE': '',
#  'NATURES HAND': '',
#  'NESTLE': '',
#  'NESTLE DRUMSTICK': '',
#  'NESTLE TOLL HOUSE': '',
#  'NESTLÉ': '',
#  'NEW ORLEANS ICE CREAM CO': '',
#  'NEW ORLEANS ICE CREAM COMPANY': '',
#  "NICK'S": '',
#  'NOOSA': '',
#  'NORTH STAR': '',
#  "O'MY DAIRY FREE": '',
#  'OATLY': '',
#  'OBERWEIS': '',
#  'OLD FASHIONED': '',
#  "OLIVIA'S ICE CREAM COOKIE BITES": '',
#  'ORASELLA': '',
#  'OREO': '',
#  'ORGANIC NECTARS': '',
#  'ORGANIC SOY DELICIOUS': '',
#  'OTTER POPS': '',
#  'OUTSHINE': '',
#  'P$$T': '',
#  'PACE': '',
#  'PALEO PASSION FOODS': '',
#  'PARADIGM FOODWORKS': '',
#  'PARTAKE': '',
#  'PASSION GROWERS': '',
#  'PAYASO': '',
#  'PEEKABOO ICE CREAM': '',
#  "PHILLY'S ITALIAN ICE": '',
#  'PHILLYSWIRL': '',
#  'PICK N SAVE': '',
#  'PLANET OAT': '',
#  'PLEASE & THANK YOU': '',
#  'POP ICE': '',
#  'POPSICLE': '',
#  'PRAIRIE FARMS': '',
#  'PRIVATE SELECTION': '',
#  'PRIVATE SELECTION RESERVE': '',
#  'PRODUCERS DAIRY': '',
#  'PROOF': '',
#  'PROYO': '',
#  'PSST': '',
#  'PURELY DECADENT': '',
#  'PURITY': '',
#  'PURPLE DOOR ICE CREAM': '',
#  'RAISED GLUTEN FREE': '',
#  'REBEL': '',
#  'REBEL ICE CREAM': '',
#  "REESE'S": '',
#  'REHARVEST PROVISIONS': '',
#  "RICH'S": '',
#  'ROBERT ROTHSCHILD FARM': '',
#  'ROLO': '',
#  'ROSEBUD ICE CREAM': '',
#  'ROUNDYS': '',
#  'ROUNDYS ORGANICS': '',
#  'ROUNDYS SELECT': '',
#  'RUBY JEWEL': '',
#  'RUBY JEWEL LLC': '',
#  'RUSSELL': '',
#  'SACRED SERVE': '',
#  'SALTY SWEET': '',
#  'SAMBAZON': '',
#  'SANDERS': '',
#  'SCHOEPS': '',
#  'SCOOPSIE DAISY': '',
#  'SHAO MEI': '',
#  'SHARONS': '',
#  "SHEILA G'S": '',
#  'SIMPLE TRUTH': '',
#  'SIMPLE TRUTH ORGANIC': '',
#  'SKINNY COW': '',
#  'SKITTLES': '',
#  "SMITH'S": '',
#  'SMITHS': '',
#  "SMUCKER'S": '',
#  'SNICKERS': '',
#  'SNOQUALMIE ICE CREAM': '',
#  'SNOW MONKEY': '',
#  'SNWTM ICE POPS 10CT': '',
#  'SO DELICIOUS': '',
#  'SO DELICIOUS DAIRY FREE': '',
#  'SODA POPS': '',
#  'SOLERO': '',
#  'SONIC': '',
#  'SORBABES': '',
#  'SOUR PATCH KIDS': '',
#  'ST ROCKY ROAD OAT DESSERT': '',
#  'STEVES ICE CREAM': '',
#  'STO': '',
#  'STONEWALL KITCHEN': '',
#  'STONYFIELD FARM': '',
#  'STONYFIELD ORGANIC': '',
#  'STRAUS FAMILY CREAMERY': '',
#  'STREETPOPS': '',
#  "STROH'S": '',
#  'SWEET ACTION ICE CREAM': '',
#  'SWEET MAGNOLIA GELATO CO.': '',
#  'SWEET NOTHINGS': '',
#  'SWEETKIWI': '',
#  'SWELL BY PROYO': '',
#  'TALENTI': '',
#  'TALENTI GELATO': '',
#  'TALENTI GELATO & SORBETTO': '',
#  'TAMPICO BEVERAGES INC.': '',
#  'TASTY': '',
#  'TASTY KAKE': '',
#  'TASTYKAKE': '',
#  'TAYLOR MADE GLUTEN FREE BAKERY': '',
#  'THE CHEESECAKE FACTORY': '',
#  'THE CHEESECAKE FACTORY AT HOME': '',
#  'THE CHOCOLATE MOOSE': '',
#  'THE COMFY COW': '',
#  'THE FROZEN FARMER': '',
#  'THE GELATO FIASCO': '',
#  'THE ORIGINAL CHIPWICH': '',
#  'THE SILVER PALATE KITCHENS': '',
#  "THELMA'S": '',
#  'THREE TWINS': '',
#  'THREE TWINS ICE CREAM': '',
#  'TILLAMOOK': '',
#  'TILLAMOOK COUNTY CREAMERY ASSOCIATION': '',
#  'TOFT': '',
#  "TOFT'S": '',
#  'TOFTS': '',
#  'TOFUTTI': '',
#  'TOLL HOUSE': '',
#  'TOPPINGS': '',
#  'TRU FRU HYPER-CHILLED GRAB & SHARE': '',
#  'TRUFF': '',
#  'TURKEY HILL': '',
#  'TURNER DAIRY': '',
#  'TURNERS': '',
#  'TUSCANINI': '',
#  'TWIX': '',
#  'TZALIS': '',
#  'UDF BRAND': '',
#  'UMPQUA': '',
#  'UMPQUA DAIRY COMPANY': '',
#  'UNBRANDED': '',
#  "UNCLE HARRY'S": '',
#  "UNCLE MATT'S": '',
#  'UNILEVER': '',
#  'UNITED DAIRY FARMERS': '',
#  'UPSTAR NUTRITION, LLC': '',
#  'VAN LEEUWEN': '',
#  'VAN LEEUWEN ICE CREAM': '',
#  'VELET': '',
#  'VELVET': '',
#  'VELVET ICE CREAM': '',
#  'VELVET ICE CREAM CO INC': '',
#  'VELVET ICE CREAM CO INC.': '',
#  'VERO': '',
#  'VITA': '',
#  'VITALICIOUS': '',
#  'WALDEN FARMS': '',
#  'WALDEN FARMS CALORIE FREE SPECIALTI': '',
#  'WARHEADS': '',
#  'WEIGHT WATCHERS': '',
#  "WELCH'S": '',
#  'WHIDBEY ISLAND ICE CREAM': '',
#  "WHIT'S JOHNSTOWN": '',
#  'WHOLE FRUIT': '',
#  'WHOLLY WHOLESOME': '',
#  'WICKED': '',
#  'WICKED KITCHEN': '',
#  "WILCOXSON'S ICE CREAM": '',
#  'WILCOXSONS': '',
#  'WILDGOOD': '',
#  "WINEGAR'S ICE CREAM": '',
#  'WINEGARS ICE CREAM': '',
#  'WONKA': '',
#  'WW': '',
#  'WYLERS ITALIAN ICE': '',
#  'YARNELL': '',
#  "YARNELL'S": '',
#  'YARNELLS': '',
#  'YASSO': '',
#  'YASSO FROZEN GREEK YOGURT': '',
#  'YASSO FROZEN GREEK YOGURT, MINT POPPABLE - 6CT': ''}
